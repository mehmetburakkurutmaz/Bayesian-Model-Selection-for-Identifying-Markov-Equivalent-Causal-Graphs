# %% [markdown]
# # Accuracy-based BO example

# %%
include("src/BayesianCausalityOptimization.jl");

using .BayesianCausalityOptimization

valid_pairs = setdiff(1:100,[52,53,54,55,71])
tuebingen_data = BayesianCausalityOptimization.Datasets.tuebingen(valid_pairs);
#pair_ids = ["001","007","016","025","034","049","064","072","073","078","086","087","088","096","100"]
#selected_data = create_data(tuebingen_data, pair_ids, 1000);

T_max = 10
Rs = 5:5
EPOCHS = 10
M = 2
P = 10
n_iterations = 10

optimizer, optimum = bayesian_optimization(tuebingen_data, T_max;Rs=Rs, EPOCHS=EPOCHS, M=M, P=P, 
                                            n_iterations=n_iterations)

# %% [markdown]
# # Likelihood-based BO

# %%
include("src/BayesianCausalityOptimization.jl");
include("src/BayesianCausality.jl");
include("src/Datasets.jl");
include("src/Misc.jl");

using .Misc, .BayesianCausality, .BayesianCausalityOptimization
using .Datasets
using Statistics, Distributions
using SpecialFunctions, LinearAlgebra
import Base.Iterators: product
import Random: randperm, seed!
using BayesOpt
import Base.Iterators: enumerate
import Base.Filesystem: mkpath

SEED = 100
seed!(SEED)
RESULTS_PATH = "./results/tuebingen/vb-hp-opt"
PARAMS_PATH = "./params";

# %%
valid_pairs = setdiff(1:100,[52,53,54,55,71])
tuebingen_data = BayesianCausalityOptimization.Datasets.tuebingen(valid_pairs);
# Out:
# ┌ Warning: readtable is deprecated, use CSV.read from the CSV package instead
# │   caller = ip:0x0
# └ @ Core :-1

# %%
redirect_stdout(prepare_empty_parameter_dictionary(1:5, tuebingen_data[1:3]), stdout)
# Out:
# UndefVarError: prepare_empty_parameter_dictionary not defined
#
# Stacktrace:
#  [1] top-level scope at In[3]:1

# %%
function prepare_empty_parameter_dictionary(Rs::UnitRange{Int64}, data::Array{Dict{Symbol,Any},1})
    DIRECTION = ['>','<', '^']
    resulting_parameters = Dict()
    likelihoods = Dict()
    for (id, pair) ∈ enumerate(data)
        resulting_parameters[pair[:id]] = Dict()
        likelihoods[pair[:id]] = Dict()
        for R in Rs
            resulting_parameters[pair[:id]][R] = Dict()
            likelihoods[pair[:id]][R] = Dict()
            for direction in DIRECTION
                resulting_parameters[pair[:id]][R][direction] = Dict()
                likelihoods[pair[:id]][R][direction] = Dict()
            end
        end
    end
    return resulting_parameters, likelihoods
end

function bayesian_optimization_likelihood(xⁿ, yⁿ; R, EPOCHS, M, P, n_iterations, m₁, m₂)
    config = ConfigParameters()        # calls initialize_parameters_to_default of the C API
    config.n_iterations = n_iterations;
    config.verbose_level = 0
    set_kernel!(config, "kMaternARD5")  # calls set_kernel of the C API
    config.sc_type = SC_MAP;
    f((γ, λ₁, λ₂, a₁, a₂, b₁, b₂)) = -v_bayes([xⁿ yⁿ],R;M=M,γ=exp(γ),m₁=m₁,m₂=m₂,λ₁=exp(λ₁),λ₂=exp(λ₂),
        a₁=exp(a₁),a₂=exp(a₂),b₁=exp(b₁),b₂=exp(b₂),EPOCHS=EPOCHS)[1][end]
    param_keys = ["γ", "λ₁", "λ₂", "a₁", "a₂", "b₁", "b₂"]
    lowerbound = [log(.0001), log(.0001), log(.0001), log(.0001), log(.0001), log(.0001), log(.0001)]; 
    upperbound = [log(10000.), log(10000.), log(10000.), log(10000.), log(10000.), log(10000.), log(10000.)];
    @time optimizer, optimum = bayes_optimization(f, lowerbound, upperbound, config)
    return Dict(zip(param_keys, optimizer)), optimum
    end;
                    
function vb_hyperparameter_optimization(data,T_max=Inf; name="hp_opt_likelihood", M=1, P=1, Rs=1:1, m₁=0.0, m₂=0.0,
        EPOCHS=1, warm_start_type="free", n_iterations=200, norm=true)
    mkpath("$RESULTS_PATH/$(name)_$(warm_start_type)")
    DIRECTION = ['>','<', '^']
    parameters, likelihoods = prepare_empty_parameter_dictionary(Rs, data)
    for (id,pair) ∈ enumerate(data)
    	print(pair[:id],"...\t\t\t")
        T = length(pair[:X])
        perm = randperm(T)[1:Int(min(T,T_max))]
        x, y = pair[:X][perm], pair[:Y][perm]
        for R in Rs
            println(" ", R)
            xⁿ = norm ? (x .- mean(x)) / std(x) : x
            yⁿ = norm ? (y .- mean(y)) / std(y) : y
            parameters[pair[:id]][R]['^'], likelihoods[pair[:id]][R]['^'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=1, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
            parameters[pair[:id]][R]['>'], likelihoods[pair[:id]][R]['>'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=M, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
            parameters[pair[:id]][R]['<'], likelihoods[pair[:id]][R]['<'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=M, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
        end        
    end
    metaparameters = Dict("M"=>M, "EPOCHS"=>EPOCHS, "P"=>P, "m₁"=>m₁, "m₂"=>m₂, "T_max"=>T_max, 
        "Rs"=>Rs, "warm_start_type"=>warm_start_type, "n_iterations"=>n_iterations, 
        "SEED"=>SEED, "norm"=>norm)
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/metaparameters.json", metaparameters=metaparameters)
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/parameters.json", parameters=parameters);
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/likelihoods.json", likelihoods=likelihoods);
    end;

# %%
vb_hyperparameter_optimization(tuebingen_data[26:50],1000; name="hp_opt_likelihood_2", M=4, P=100, Rs=1:5, m₁=0.0, m₂=0.0,
        EPOCHS=200, warm_start_type="free", n_iterations=200)
# Out:
# pair0026...			 1
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:441
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:441
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:443
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:443
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:446
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:446
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:450
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:450
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:450
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:450
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:450
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:450
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:451
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:451
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:452
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:452
#  21.474815 seconds (8.17 M allocations: 580.980 MiB, 0.54% gc time)
#  18.167388 seconds (8.16 M allocations: 908.432 MiB, 1.02% gc time)
#  15.542065 seconds (8.16 M allocations: 908.432 MiB, 1.13% gc time)
#  2
#  41.125469 seconds (174.26 M allocations: 12.333 GiB, 6.27% gc time)
#  54.840533 seconds (235.51 M allocations: 25.473 GiB, 9.41% gc time)
#  53.979178 seconds (221.94 M allocations: 24.018 GiB, 7.84% gc time)
#  3
# 121.999675 seconds (992.36 M allocations: 70.999 GiB, 12.13% gc time)
# 297.205510 seconds (1.73 G allocations: 190.307 GiB, 12.62% gc time)
# 294.373410 seconds (1.67 G allocations: 184.459 GiB, 13.59% gc time)
#  4
# 214.124535 seconds (1.94 G allocations: 139.153 GiB, 12.79% gc time)
# 394.319416 seconds (2.44 G allocations: 270.890 GiB, 12.16% gc time)
# 403.983985 seconds (2.44 G allocations: 270.880 GiB, 13.60% gc time)
#  5
# 251.241481 seconds (2.29 G allocations: 164.448 GiB, 14.22% gc time)
# 474.651900 seconds (2.49 G allocations: 276.580 GiB, 13.18% gc time)
# 573.327515 seconds (2.88 G allocations: 320.581 GiB, 13.16% gc time)
# pair0027...			 1
#  26.581069 seconds (7.32 M allocations: 541.813 MiB, 0.53% gc time)
#  18.856303 seconds (8.16 M allocations: 908.432 MiB, 1.13% gc time)
#  22.217337 seconds (8.16 M allocations: 908.432 MiB, 0.98% gc time)
#  2
#  30.782713 seconds (52.35 M allocations: 3.701 GiB, 2.98% gc time)
#  39.523211 seconds (76.95 M allocations: 8.288 GiB, 5.18% gc time)
#  36.355138 seconds (67.36 M allocations: 7.247 GiB, 4.86% gc time)
#  3
#  85.814942 seconds (482.50 M allocations: 34.506 GiB, 10.61% gc time)
# 100.484556 seconds (370.74 M allocations: 40.780 GiB, 10.46% gc time)
# 123.183403 seconds (462.42 M allocations: 50.871 GiB, 11.41% gc time)
#  4
# 228.789617 seconds (1.58 G allocations: 113.394 GiB, 13.15% gc time)
# 318.455868 seconds (1.46 G allocations: 162.000 GiB, 11.93% gc time)
# 372.078664 seconds (1.77 G allocations: 196.333 GiB, 13.38% gc time)
#  5
# 326.129383 seconds (2.40 G allocations: 172.315 GiB, 14.33% gc time)
# 495.879842 seconds (2.50 G allocations: 276.626 GiB, 12.87% gc time)
# 537.438068 seconds (2.76 G allocations: 306.447 GiB, 12.85% gc time)
# pair0028...			 1
#  21.290748 seconds (7.32 M allocations: 541.813 MiB, 0.58% gc time)
#  25.618090 seconds (8.16 M allocations: 908.432 MiB, 0.75% gc time)
#  25.535805 seconds (8.16 M allocations: 908.432 MiB, 0.75% gc time)
#  2
#  89.787695 seconds (489.27 M allocations: 34.703 GiB, 9.17% gc time)
# 235.476246 seconds (1.02 G allocations: 110.875 GiB, 11.25% gc time)
# 209.270222 seconds (893.72 M allocations: 97.097 GiB, 11.55% gc time)
#  3
# 145.205853 seconds (935.08 M allocations: 66.888 GiB, 11.84% gc time)
# 249.616130 seconds (1.16 G allocations: 127.884 GiB, 11.07% gc time)
# 215.905969 seconds (993.01 M allocations: 109.263 GiB, 11.74% gc time)
#  4
# 209.594731 seconds (1.48 G allocations: 105.951 GiB, 12.40% gc time)
# 345.660778 seconds (1.64 G allocations: 180.996 GiB, 13.54% gc time)
# 325.420690 seconds (1.56 G allocations: 173.003 GiB, 12.30% gc time)
#  5
# 232.933075 seconds (1.69 G allocations: 121.046 GiB, 13.37% gc time)
# 408.585780 seconds (2.00 G allocations: 221.667 GiB, 14.41% gc time)
# - 08:25:31.436482 ERROR: nlopt failure
# 325.022026 seconds (1.61 G allocations: 178.011 GiB, 14.34% gc time)
# pair0029...			 1
#  26.294542 seconds (7.32 M allocations: 541.813 MiB, 0.47% gc time)
#  22.795511 seconds (8.16 M allocations: 908.432 MiB, 0.98% gc time)
#  24.365921 seconds (8.16 M allocations: 908.432 MiB, 0.91% gc time)
#  2
#  86.347033 seconds (450.24 M allocations: 31.932 GiB, 9.48% gc time)
#  94.292655 seconds (329.52 M allocations: 35.744 GiB, 8.61% gc time)
#  98.520533 seconds (356.49 M allocations: 38.671 GiB, 9.05% gc time)
#  3
# 186.050770 seconds (1.22 G allocations: 87.378 GiB, 12.40% gc time)
# 351.519743 seconds (1.63 G allocations: 179.523 GiB, 12.59% gc time)
# 384.667774 seconds (1.78 G allocations: 195.766 GiB, 11.94% gc time)
#  4
# 246.994063 seconds (1.75 G allocations: 124.908 GiB, 12.85% gc time)
# 462.545923 seconds (2.20 G allocations: 243.087 GiB, 13.87% gc time)
# 527.957106 seconds (2.46 G allocations: 272.957 GiB, 15.06% gc time)
#  5
# 278.004871 seconds (1.97 G allocations: 141.174 GiB, 14.21% gc time)
# 599.993588 seconds (2.95 G allocations: 327.314 GiB, 13.76% gc time)
# 589.170519 seconds (2.89 G allocations: 319.750 GiB, 14.55% gc time)
# pair0030...			 1
#  21.451588 seconds (7.32 M allocations: 541.813 MiB, 0.65% gc time)
#  23.548647 seconds (8.16 M allocations: 908.432 MiB, 0.86% gc time)
#  23.048988 seconds (8.16 M allocations: 908.432 MiB, 0.95% gc time)
#  2
# 128.389442 seconds (721.93 M allocations: 51.200 GiB, 10.73% gc time)
# 153.525773 seconds (597.38 M allocations: 64.825 GiB, 10.71% gc time)
# 204.639938 seconds (821.87 M allocations: 89.245 GiB, 11.09% gc time)
#  3
# 157.376264 seconds (947.69 M allocations: 67.792 GiB, 12.23% gc time)
# - 09:45:59.392376 ERROR: nlopt failure
# 136.356552 seconds (642.08 M allocations: 70.619 GiB, 12.99% gc time)
# 296.052472 seconds (1.33 G allocations: 146.195 GiB, 13.26% gc time)
#  4
# 191.274919 seconds (1.31 G allocations: 94.038 GiB, 12.70% gc time)
# 299.302934 seconds (1.39 G allocations: 153.991 GiB, 12.03% gc time)
# 351.459213 seconds (1.64 G allocations: 181.723 GiB, 13.08% gc time)
#  5
# 270.713338 seconds (1.96 G allocations: 140.492 GiB, 14.26% gc time)
# 389.698384 seconds (1.87 G allocations: 207.555 GiB, 15.10% gc time)
# 558.909714 seconds (2.67 G allocations: 296.771 GiB, 14.79% gc time)
# pair0031...			 1
#  23.218884 seconds (7.32 M allocations: 541.813 MiB, 0.65% gc time)
#  23.039677 seconds (8.16 M allocations: 908.432 MiB, 1.00% gc time)
#  26.005677 seconds (8.16 M allocations: 908.432 MiB, 0.90% gc time)
#  2
# 100.467783 seconds (502.78 M allocations: 35.643 GiB, 10.40% gc time)
# 198.168668 seconds (783.11 M allocations: 85.009 GiB, 11.71% gc time)
# 208.445834 seconds (828.39 M allocations: 89.931 GiB, 12.67% gc time)
#  3
# 168.208494 seconds (1.02 G allocations: 72.628 GiB, 13.57% gc time)
# - 10:40:53.023105 ERROR: nlopt failure
# 188.591698 seconds (845.32 M allocations: 92.916 GiB, 14.02% gc time)
# 289.129851 seconds (1.24 G allocations: 135.966 GiB, 12.72% gc time)
#  4
# 209.669252 seconds (1.40 G allocations: 100.234 GiB, 12.91% gc time)
# 345.949579 seconds (1.61 G allocations: 177.479 GiB, 14.54% gc time)
# 343.958132 seconds (1.55 G allocations: 171.349 GiB, 15.26% gc time)
#  5
# 261.388921 seconds (1.80 G allocations: 129.141 GiB, 14.55% gc time)
# 396.864324 seconds (1.85 G allocations: 204.419 GiB, 14.51% gc time)
# 448.080124 seconds (2.16 G allocations: 240.210 GiB, 14.61% gc time)
# pair0032...			 1
#  24.496822 seconds (7.32 M allocations: 541.813 MiB, 0.67% gc time)
#  23.430348 seconds (8.16 M allocations: 908.432 MiB, 1.05% gc time)
#  23.668971 seconds (8.16 M allocations: 908.432 MiB, 1.02% gc time)
#  2
#  60.792793 seconds (260.32 M allocations: 18.459 GiB, 8.65% gc time)
# - 11:22:14.228047 ERROR: nlopt failure
#  53.484244 seconds (219.87 M allocations: 23.858 GiB, 12.06% gc time)
# 132.269800 seconds (493.64 M allocations: 53.601 GiB, 11.38% gc time)
#  3
# - 11:24:48.950974 ERROR: nlopt failure
#  22.442299 seconds (156.57 M allocations: 11.196 GiB, 14.58% gc time)
# 194.641748 seconds (809.06 M allocations: 88.920 GiB, 12.03% gc time)
# 400.253997 seconds (1.82 G allocations: 200.310 GiB, 13.74% gc time)
#  4
# 180.296066 seconds (1.09 G allocations: 77.728 GiB, 12.82% gc time)
# 232.272572 seconds (985.57 M allocations: 108.897 GiB, 14.86% gc time)
# 415.539870 seconds (1.93 G allocations: 213.464 GiB, 14.21% gc time)
#  5
# 260.585727 seconds (1.79 G allocations: 128.268 GiB, 13.87% gc time)
# 531.747093 seconds (2.49 G allocations: 276.847 GiB, 15.83% gc time)
# 413.922221 seconds (1.81 G allocations: 201.205 GiB, 15.10% gc time)
# pair0033...			 1
#  20.529184 seconds (2.78 M allocations: 214.448 MiB, 0.29% gc time)
# - 12:09:00.015975 ERROR: nlopt failure
#   1.231719 seconds (849.18 k allocations: 94.402 MiB, 1.70% gc time)
#  27.101016 seconds (3.07 M allocations: 341.798 MiB, 0.33% gc time)
#  2
#  46.866908 seconds (89.16 M allocations: 6.558 GiB, 3.98% gc time)
#  72.577504 seconds (148.30 M allocations: 16.087 GiB, 5.87% gc time)
#  55.071333 seconds (96.72 M allocations: 10.480 GiB, 5.07% gc time)
#  3
#  62.860920 seconds (191.37 M allocations: 14.135 GiB, 6.70% gc time)
# 155.132700 seconds (448.58 M allocations: 49.376 GiB, 8.20% gc time)
# 171.541268 seconds (495.03 M allocations: 54.525 GiB, 8.72% gc time)
#  4
# 144.390127 seconds (497.08 M allocations: 36.664 GiB, 6.81% gc time)
# 255.077159 seconds (806.53 M allocations: 89.315 GiB, 10.45% gc time)
# 175.225088 seconds (515.28 M allocations: 56.890 GiB, 10.10% gc time)
#  5
# 151.589634 seconds (572.00 M allocations: 42.268 GiB, 8.20% gc time)
# 230.111424 seconds (715.73 M allocations: 79.439 GiB, 11.41% gc time)
# 201.494088 seconds (597.37 M allocations: 66.215 GiB, 11.16% gc time)
# pair0034...			 1
#  22.008505 seconds (2.78 M allocations: 214.448 MiB, 0.28% gc time)
#  22.548902 seconds (3.10 M allocations: 345.053 MiB, 0.49% gc time)
#  26.006148 seconds (3.07 M allocations: 341.798 MiB, 0.39% gc time)
#  2
#  81.182230 seconds (225.67 M allocations: 16.607 GiB, 6.06% gc time)
#  60.926303 seconds (123.67 M allocations: 13.399 GiB, 6.26% gc time)
#  73.630853 seconds (162.95 M allocations: 17.672 GiB, 5.96% gc time)
#  3
# 103.778643 seconds (339.18 M allocations: 25.052 GiB, 6.55% gc time)
# 171.055225 seconds (496.28 M allocations: 54.630 GiB, 8.11% gc time)
# 192.081918 seconds (586.63 M allocations: 64.592 GiB, 8.62% gc time)
#  4
# 108.780908 seconds (368.91 M allocations: 27.201 GiB, 6.61% gc time)
# 262.008748 seconds (829.36 M allocations: 91.805 GiB, 10.12% gc time)
# 235.733642 seconds (735.66 M allocations: 81.387 GiB, 10.38% gc time)
#  5
# 208.708520 seconds (834.83 M allocations: 61.691 GiB, 8.36% gc time)
# 210.260490 seconds (659.91 M allocations: 73.164 GiB, 11.16% gc time)
# 247.180190 seconds (773.50 M allocations: 85.867 GiB, 11.44% gc time)
# pair0035...			 1
#  24.105741 seconds (2.78 M allocations: 214.448 MiB, 0.24% gc time)
#  18.853359 seconds (3.07 M allocations: 341.798 MiB, 0.56% gc time)
#  25.901978 seconds (3.07 M allocations: 341.798 MiB, 0.36% gc time)
#  2
#  49.588909 seconds (102.71 M allocations: 7.557 GiB, 4.34% gc time)
#  64.267668 seconds (122.27 M allocations: 13.263 GiB, 6.01% gc time)
#  54.797611 seconds (118.01 M allocations: 12.802 GiB, 5.76% gc time)
#  3
#  55.137916 seconds (162.13 M allocations: 11.975 GiB, 5.39% gc time)
#  85.481327 seconds (229.52 M allocations: 25.231 GiB, 6.78% gc time)
#  89.493016 seconds (231.87 M allocations: 25.446 GiB, 6.81% gc time)
#  4
#  90.083369 seconds (302.50 M allocations: 22.307 GiB, 6.38% gc time)
# 171.704485 seconds (514.74 M allocations: 56.935 GiB, 9.05% gc time)
# 153.891106 seconds (457.35 M allocations: 50.466 GiB, 9.36% gc time)
#  5
# 119.909930 seconds (447.73 M allocations: 33.081 GiB, 7.64% gc time)
# 210.087045 seconds (675.54 M allocations: 75.006 GiB, 11.16% gc time)
# 187.886601 seconds (564.95 M allocations: 62.410 GiB, 10.00% gc time)
# pair0036...			 1
#  23.394040 seconds (2.78 M allocations: 214.448 MiB, 0.23% gc time)
#  20.070767 seconds (3.07 M allocations: 341.798 MiB, 0.44% gc time)
#  17.564907 seconds (3.07 M allocations: 341.798 MiB, 0.60% gc time)
#  2
#  44.923694 seconds (90.68 M allocations: 6.673 GiB, 4.21% gc time)
#  67.539489 seconds (134.26 M allocations: 14.568 GiB, 6.57% gc time)
#  56.636003 seconds (114.32 M allocations: 12.400 GiB, 6.47% gc time)
#  3
#  75.156668 seconds (228.40 M allocations: 16.872 GiB, 6.25% gc time)
#  97.502100 seconds (260.94 M allocations: 28.709 GiB, 8.05% gc time)
# 115.448981 seconds (295.05 M allocations: 32.485 GiB, 6.49% gc time)
#  4
# 101.047092 seconds (367.27 M allocations: 27.084 GiB, 7.08% gc time)
# 153.984011 seconds (471.06 M allocations: 52.095 GiB, 8.71% gc time)
# 172.116694 seconds (522.60 M allocations: 57.785 GiB, 9.51% gc time)
#  5
# 136.359151 seconds (524.71 M allocations: 38.771 GiB, 7.90% gc time)
# 205.086365 seconds (638.57 M allocations: 70.888 GiB, 10.76% gc time)
# 190.591849 seconds (584.84 M allocations: 64.914 GiB, 10.91% gc time)
# pair0037...			 1
#  21.197921 seconds (2.78 M allocations: 214.448 MiB, 0.32% gc time)
#  23.465511 seconds (3.07 M allocations: 341.798 MiB, 0.47% gc time)
#  28.064075 seconds (3.07 M allocations: 341.798 MiB, 0.36% gc time)
#  2
#  54.256497 seconds (116.52 M allocations: 8.574 GiB, 4.62% gc time)
#  72.961569 seconds (147.06 M allocations: 15.957 GiB, 6.65% gc time)
#  69.516610 seconds (143.57 M allocations: 15.577 GiB, 7.56% gc time)
#  3
# 119.792684 seconds (395.13 M allocations: 29.191 GiB, 7.88% gc time)
# 128.344783 seconds (328.45 M allocations: 36.091 GiB, 8.68% gc time)
#  99.756308 seconds (269.80 M allocations: 29.698 GiB, 7.76% gc time)
#  4
# 153.808302 seconds (560.74 M allocations: 41.360 GiB, 7.81% gc time)
# 209.340735 seconds (627.06 M allocations: 69.408 GiB, 9.76% gc time)
# 164.890258 seconds (467.82 M allocations: 51.729 GiB, 9.69% gc time)
#  5
# 194.377639 seconds (750.62 M allocations: 55.467 GiB, 8.65% gc time)
# 172.407935 seconds (518.96 M allocations: 57.555 GiB, 11.44% gc time)
# - 14:25:38.312208 ERROR: nlopt failure
#  32.268676 seconds (106.96 M allocations: 11.820 GiB, 12.73% gc time)
# pair0038...			 1
#  24.177974 seconds (5.64 M allocations: 420.372 MiB, 0.52% gc time)
#  24.649082 seconds (6.28 M allocations: 698.224 MiB, 0.87% gc time)
#  28.415745 seconds (6.28 M allocations: 698.224 MiB, 0.76% gc time)
#  2
# - 14:27:54.307641 ERROR: nlopt failure
#  58.731307 seconds (252.01 M allocations: 17.950 GiB, 9.35% gc time)
# 106.303179 seconds (338.37 M allocations: 36.585 GiB, 10.31% gc time)
#  98.872709 seconds (336.61 M allocations: 36.395 GiB, 9.76% gc time)
#  3
# 161.501471 seconds (885.16 M allocations: 63.691 GiB, 11.29% gc time)
# 227.393573 seconds (894.69 M allocations: 98.425 GiB, 11.98% gc time)
# 311.378735 seconds (1.25 G allocations: 137.195 GiB, 12.71% gc time)
#  4
# 192.706201 seconds (1.07 G allocations: 77.219 GiB, 12.05% gc time)
# 312.394080 seconds (1.28 G allocations: 141.131 GiB, 14.10% gc time)
# 410.261238 seconds (1.75 G allocations: 193.757 GiB, 13.43% gc time)
#  5
# 230.845578 seconds (1.37 G allocations: 98.702 GiB, 12.54% gc time)
# 507.855321 seconds (2.20 G allocations: 244.478 GiB, 13.97% gc time)
# 400.983286 seconds (1.70 G allocations: 188.739 GiB, 14.18% gc time)
# pair0039...			 1
#  22.197437 seconds (3.12 M allocations: 238.932 MiB, 0.29% gc time)
#  25.955981 seconds (3.46 M allocations: 384.182 MiB, 0.43% gc time)
#  23.303565 seconds (3.46 M allocations: 384.182 MiB, 0.47% gc time)
#  2
#  50.526931 seconds (114.17 M allocations: 8.341 GiB, 5.20% gc time)
#  72.621045 seconds (150.98 M allocations: 16.366 GiB, 6.81% gc time)
#  66.714089 seconds (142.69 M allocations: 15.464 GiB, 7.38% gc time)
#  3
# 107.556058 seconds (367.56 M allocations: 27.002 GiB, 7.91% gc time)
# - 15:24:20.054291 ERROR: nlopt failure
#  56.297780 seconds (179.16 M allocations: 19.696 GiB, 10.85% gc time)
# 133.894074 seconds (358.55 M allocations: 39.413 GiB, 8.59% gc time)
#  4
# 108.325051 seconds (374.20 M allocations: 27.451 GiB, 7.81% gc time)
# 211.953922 seconds (680.00 M allocations: 75.172 GiB, 9.80% gc time)
# 241.081264 seconds (768.97 M allocations: 85.068 GiB, 10.71% gc time)
#  5
# 154.732625 seconds (605.01 M allocations: 44.481 GiB, 9.00% gc time)
# 241.059765 seconds (786.82 M allocations: 87.320 GiB, 11.67% gc time)
# 354.544322 seconds (1.20 G allocations: 133.248 GiB, 11.73% gc time)
# pair0040...			 1
# - 15:48:26.222235 ERROR: nlopt failure
#   0.544163 seconds (859.82 k allocations: 64.173 MiB, 3.27% gc time)
#  23.038702 seconds (6.09 M allocations: 677.460 MiB, 0.83% gc time)
#  24.134815 seconds (6.09 M allocations: 677.460 MiB, 0.79% gc time)
#  2
#  76.164197 seconds (337.31 M allocations: 24.101 GiB, 9.15% gc time)
# 156.981315 seconds (545.91 M allocations: 59.274 GiB, 11.76% gc time)
# 100.159240 seconds (324.95 M allocations: 35.240 GiB, 8.98% gc time)
#  3
# 132.555786 seconds (651.33 M allocations: 46.900 GiB, 10.06% gc time)
# 216.239653 seconds (826.02 M allocations: 90.870 GiB, 11.11% gc time)
# 247.475237 seconds (946.48 M allocations: 104.180 GiB, 12.19% gc time)
#  4
# 212.722896 seconds (1.23 G allocations: 88.440 GiB, 11.95% gc time)
# 303.373093 seconds (1.26 G allocations: 139.169 GiB, 13.94% gc time)
# 307.199955 seconds (1.27 G allocations: 140.559 GiB, 13.65% gc time)
#  5
# 238.197524 seconds (1.43 G allocations: 103.014 GiB, 12.63% gc time)
# 381.928792 seconds (1.65 G allocations: 182.819 GiB, 13.14% gc time)
# 381.309628 seconds (1.64 G allocations: 182.072 GiB, 13.75% gc time)
# pair0041...			 1
#  21.291831 seconds (5.68 M allocations: 423.378 MiB, 0.52% gc time)
#  25.999334 seconds (6.32 M allocations: 703.421 MiB, 0.72% gc time)
#  23.178392 seconds (6.32 M allocations: 703.421 MiB, 0.80% gc time)
#  2
#  67.586613 seconds (257.03 M allocations: 18.339 GiB, 7.87% gc time)
#  89.749915 seconds (286.60 M allocations: 31.071 GiB, 9.59% gc time)
#  97.916346 seconds (317.16 M allocations: 34.394 GiB, 9.73% gc time)
#  3
# 151.661524 seconds (857.25 M allocations: 61.677 GiB, 10.77% gc time)
# 216.022334 seconds (909.60 M allocations: 99.949 GiB, 11.07% gc time)
# - 16:48:50.482229 ERROR: nlopt failure
# 129.260033 seconds (560.65 M allocations: 61.707 GiB, 12.17% gc time)
#  4
# 180.618400 seconds (1.10 G allocations: 78.841 GiB, 11.64% gc time)
# 390.663715 seconds (1.69 G allocations: 187.321 GiB, 13.67% gc time)
# 325.100153 seconds (1.39 G allocations: 153.721 GiB, 13.96% gc time)
#  5
# 194.171576 seconds (1.18 G allocations: 85.417 GiB, 11.72% gc time)
# 462.650804 seconds (2.15 G allocations: 239.243 GiB, 12.50% gc time)
# 388.947955 seconds (1.79 G allocations: 197.841 GiB, 12.52% gc time)
# pair0042...			 1
#  22.106559 seconds (7.32 M allocations: 541.813 MiB, 0.51% gc time)
#  25.785372 seconds (8.16 M allocations: 908.432 MiB, 0.76% gc time)
#  23.269370 seconds (8.16 M allocations: 908.432 MiB, 0.82% gc time)
#  2
#  63.698500 seconds (289.77 M allocations: 20.540 GiB, 7.89% gc time)
# 146.406129 seconds (579.22 M allocations: 62.861 GiB, 10.44% gc time)
# 194.632407 seconds (819.84 M allocations: 89.030 GiB, 11.19% gc time)
#  3
#  89.873542 seconds (521.52 M allocations: 37.316 GiB, 10.18% gc time)
# 256.097350 seconds (1.17 G allocations: 129.132 GiB, 12.01% gc time)
# 234.431340 seconds (1.06 G allocations: 116.635 GiB, 12.93% gc time)
#  4
# 159.042161 seconds (1.06 G allocations: 75.728 GiB, 11.67% gc time)
# 357.993966 seconds (1.74 G allocations: 192.307 GiB, 13.39% gc time)
# 466.294940 seconds (2.21 G allocations: 244.183 GiB, 13.54% gc time)
#  5
# 207.245735 seconds (1.37 G allocations: 98.384 GiB, 14.02% gc time)
# 512.633750 seconds (2.37 G allocations: 263.320 GiB, 16.09% gc time)
# 479.261680 seconds (2.19 G allocations: 242.526 GiB, 15.68% gc time)
# pair0043...			 1
#  23.548469 seconds (7.32 M allocations: 541.813 MiB, 0.62% gc time)
#  26.028240 seconds (8.16 M allocations: 908.432 MiB, 0.94% gc time)
#  27.002690 seconds (8.16 M allocations: 908.432 MiB, 0.94% gc time)
#  2
# - 18:16:42.574430 ERROR: nlopt failure
#  14.472498 seconds (92.27 M allocations: 6.543 GiB, 13.17% gc time)
# 163.683398 seconds (606.97 M allocations: 65.914 GiB, 11.63% gc time)
# 140.586285 seconds (505.25 M allocations: 54.851 GiB, 11.62% gc time)
#  3
#  95.999964 seconds (521.76 M allocations: 37.326 GiB, 11.13% gc time)
# 160.684987 seconds (653.42 M allocations: 71.952 GiB, 12.30% gc time)
# 188.676828 seconds (815.86 M allocations: 89.206 GiB, 12.27% gc time)
#  4
# 169.160153 seconds (1.12 G allocations: 80.000 GiB, 13.14% gc time)
# 319.658430 seconds (1.47 G allocations: 162.414 GiB, 14.72% gc time)
# 348.335878 seconds (1.56 G allocations: 172.934 GiB, 15.17% gc time)
#  5
# 257.720627 seconds (1.80 G allocations: 129.060 GiB, 13.54% gc time)
# 396.521308 seconds (1.96 G allocations: 217.364 GiB, 13.17% gc time)
# 408.650364 seconds (2.02 G allocations: 224.097 GiB, 13.35% gc time)
# pair0044...			 1
#  20.303620 seconds (7.32 M allocations: 541.813 MiB, 0.65% gc time)
#  26.506381 seconds (8.16 M allocations: 908.432 MiB, 0.79% gc time)
#  25.352619 seconds (8.16 M allocations: 908.432 MiB, 0.82% gc time)
#  2
#  49.517934 seconds (177.50 M allocations: 12.601 GiB, 6.21% gc time)
#  96.596442 seconds (349.73 M allocations: 38.010 GiB, 9.54% gc time)
#  83.384553 seconds (288.89 M allocations: 31.395 GiB, 8.97% gc time)
#  3
# 108.979185 seconds (651.52 M allocations: 46.608 GiB, 10.42% gc time)
# 310.936849 seconds (1.42 G allocations: 156.826 GiB, 12.86% gc time)
# 118.864899 seconds (482.22 M allocations: 53.077 GiB, 11.54% gc time)
#  4
#  98.309501 seconds (665.12 M allocations: 47.600 GiB, 11.29% gc time)
# 364.882568 seconds (1.88 G allocations: 207.997 GiB, 13.18% gc time)
# 265.515602 seconds (1.36 G allocations: 151.206 GiB, 13.66% gc time)
#  5
# 144.957009 seconds (977.86 M allocations: 70.229 GiB, 11.76% gc time)
# 406.208609 seconds (2.20 G allocations: 244.260 GiB, 13.05% gc time)
# 344.901053 seconds (1.81 G allocations: 201.882 GiB, 13.56% gc time)
# pair0045...			 1
#  23.021636 seconds (7.32 M allocations: 541.813 MiB, 0.52% gc time)
#  20.757689 seconds (8.16 M allocations: 908.432 MiB, 0.92% gc time)
#  19.738651 seconds (8.16 M allocations: 908.432 MiB, 1.00% gc time)
#  2
#  47.930689 seconds (216.06 M allocations: 15.328 GiB, 7.33% gc time)
# 105.259852 seconds (446.56 M allocations: 48.501 GiB, 10.86% gc time)
# 122.191711 seconds (523.60 M allocations: 56.875 GiB, 11.50% gc time)
#  3
# 104.136289 seconds (674.06 M allocations: 48.214 GiB, 11.24% gc time)
# 179.637503 seconds (869.91 M allocations: 95.696 GiB, 12.12% gc time)
# 207.671067 seconds (1.00 G allocations: 110.133 GiB, 13.34% gc time)
#  4
# 138.901138 seconds (989.66 M allocations: 70.829 GiB, 12.88% gc time)
# 305.897618 seconds (1.57 G allocations: 173.384 GiB, 13.14% gc time)
# 324.265244 seconds (1.72 G allocations: 190.356 GiB, 13.02% gc time)
#  5
# 188.372104 seconds (1.49 G allocations: 106.886 GiB, 13.22% gc time)
# 433.918085 seconds (2.33 G allocations: 258.228 GiB, 15.22% gc time)
# 508.699522 seconds (2.71 G allocations: 301.240 GiB, 14.55% gc time)
# pair0046...			 1
#  20.171852 seconds (7.32 M allocations: 541.813 MiB, 0.62% gc time)
#  18.408997 seconds (8.16 M allocations: 908.432 MiB, 1.09% gc time)
#  21.746435 seconds (8.16 M allocations: 908.432 MiB, 0.88% gc time)
#  2
#  39.151187 seconds (147.66 M allocations: 10.476 GiB, 6.30% gc time)
#  85.842392 seconds (322.86 M allocations: 35.062 GiB, 9.29% gc time)
#  90.557443 seconds (362.22 M allocations: 39.344 GiB, 10.62% gc time)
#  3
# 110.193607 seconds (739.28 M allocations: 52.898 GiB, 11.91% gc time)
# 301.265503 seconds (1.52 G allocations: 167.775 GiB, 13.14% gc time)
# 307.032342 seconds (1.62 G allocations: 178.713 GiB, 12.59% gc time)
#  4
# 122.798867 seconds (1.03 G allocations: 73.870 GiB, 12.31% gc time)
# 262.932740 seconds (1.54 G allocations: 170.267 GiB, 14.30% gc time)
# 342.865418 seconds (2.01 G allocations: 222.243 GiB, 14.98% gc time)
#  5
# 224.114274 seconds (2.00 G allocations: 143.760 GiB, 13.55% gc time)
# 433.061355 seconds (2.68 G allocations: 298.256 GiB, 13.83% gc time)
# 424.788633 seconds (2.61 G allocations: 290.690 GiB, 14.29% gc time)
# pair0047...			 1
#  17.758386 seconds (2.15 M allocations: 168.924 MiB, 0.20% gc time)
#  19.790854 seconds (2.37 M allocations: 263.032 MiB, 0.24% gc time)
#  17.247874 seconds (2.37 M allocations: 263.032 MiB, 0.28% gc time)
#  2
#  20.236651 seconds (8.81 M allocations: 674.207 MiB, 0.68% gc time)
#  22.637363 seconds (11.76 M allocations: 1.269 GiB, 1.10% gc time)
#  21.392611 seconds (11.53 M allocations: 1.245 GiB, 1.08% gc time)
#  3
#  46.336612 seconds (43.64 M allocations: 3.272 GiB, 1.55% gc time)
#  31.973834 seconds (50.58 M allocations: 5.550 GiB, 3.57% gc time)
#  38.361588 seconds (67.23 M allocations: 7.390 GiB, 3.98% gc time)
#  4
#  48.865837 seconds (114.42 M allocations: 8.560 GiB, 3.82% gc time)
#  45.465805 seconds (77.62 M allocations: 8.529 GiB, 3.88% gc time)
#  50.315794 seconds (108.22 M allocations: 11.968 GiB, 5.04% gc time)
#  5
#  74.604422 seconds (244.93 M allocations: 18.348 GiB, 5.50% gc time)
#  46.548139 seconds (109.32 M allocations: 12.106 GiB, 5.74% gc time)
#  59.713760 seconds (154.44 M allocations: 17.121 GiB, 6.28% gc time)
# pair0048...			 1
#  18.467024 seconds (1.56 M allocations: 125.928 MiB, 0.16% gc time)
#  19.771786 seconds (1.70 M allocations: 188.621 MiB, 0.21% gc time)
#  16.737693 seconds (1.70 M allocations: 188.621 MiB, 0.22% gc time)
#  2
#  46.105503 seconds (90.06 M allocations: 6.943 GiB, 3.33% gc time)
#  58.800558 seconds (110.66 M allocations: 12.005 GiB, 4.26% gc time)
#  48.011834 seconds (84.26 M allocations: 9.139 GiB, 3.59% gc time)
#  3
#  60.249093 seconds (149.42 M allocations: 11.502 GiB, 4.19% gc time)
#  78.254330 seconds (187.71 M allocations: 20.575 GiB, 5.21% gc time)
# 109.622977 seconds (283.31 M allocations: 31.153 GiB, 5.58% gc time)
#  4
#  93.455735 seconds (271.64 M allocations: 20.830 GiB, 4.91% gc time)
# 137.271990 seconds (375.65 M allocations: 41.464 GiB, 6.65% gc time)
#  96.720685 seconds (261.90 M allocations: 28.828 GiB, 6.81% gc time)
#  5
#  88.539243 seconds (268.24 M allocations: 20.571 GiB, 5.40% gc time)
# 121.216653 seconds (337.02 M allocations: 37.162 GiB, 7.43% gc time)
# 125.662786 seconds (348.40 M allocations: 38.363 GiB, 7.57% gc time)
# pair0049...			 1
#  19.079624 seconds (2.92 M allocations: 224.420 MiB, 0.26% gc time)
#  20.284788 seconds (3.23 M allocations: 359.076 MiB, 0.38% gc time)
#  18.828519 seconds (3.23 M allocations: 359.076 MiB, 0.46% gc time)
#  2
# - 21:43:22.557092 ERROR: nlopt failure
#  11.306335 seconds (46.05 M allocations: 3.380 GiB, 6.68% gc time)
# - 21:44:18.377380 ERROR: nlopt failure
#  55.819896 seconds (173.96 M allocations: 18.886 GiB, 8.51% gc time)
#  79.180914 seconds (248.57 M allocations: 27.001 GiB, 8.80% gc time)
#  3
#  75.019146 seconds (285.57 M allocations: 21.041 GiB, 6.58% gc time)
# 117.830646 seconds (425.68 M allocations: 46.812 GiB, 10.07% gc time)
# 124.303051 seconds (453.59 M allocations: 49.807 GiB, 10.38% gc time)
#  4
#  99.388007 seconds (470.14 M allocations: 34.587 GiB, 8.62% gc time)
# 166.612498 seconds (663.91 M allocations: 73.181 GiB, 9.34% gc time)
# 156.343208 seconds (628.23 M allocations: 69.197 GiB, 9.37% gc time)
#  5
# 140.049783 seconds (714.50 M allocations: 52.679 GiB, 8.62% gc time)
# 193.894824 seconds (814.60 M allocations: 90.016 GiB, 10.69% gc time)
# 137.867593 seconds (558.28 M allocations: 61.475 GiB, 10.56% gc time)
# pair0050...			 1
#  18.398580 seconds (2.92 M allocations: 224.420 MiB, 0.27% gc time)
#  16.361249 seconds (3.23 M allocations: 359.076 MiB, 0.54% gc time)
#  16.522371 seconds (3.23 M allocations: 359.076 MiB, 0.46% gc time)
#  2
# - 22:07:13.361198 ERROR: nlopt failure
#  33.205504 seconds (107.38 M allocations: 7.879 GiB, 5.45% gc time)
#  72.964041 seconds (228.86 M allocations: 24.847 GiB, 7.84% gc time)
#  71.892616 seconds (218.44 M allocations: 23.715 GiB, 7.86% gc time)
#  3
#  75.097570 seconds (320.81 M allocations: 23.626 GiB, 7.40% gc time)
# 120.217252 seconds (440.69 M allocations: 48.335 GiB, 9.88% gc time)
# 118.707744 seconds (432.52 M allocations: 47.471 GiB, 10.10% gc time)
#  4
# 141.483173 seconds (716.66 M allocations: 52.735 GiB, 8.06% gc time)
# 142.548934 seconds (604.85 M allocations: 66.586 GiB, 8.36% gc time)
# - 22:20:43.834418 ERROR: nlopt failure
#  67.558430 seconds (313.62 M allocations: 34.514 GiB, 8.97% gc time)
#  5
# 105.135998 seconds (557.53 M allocations: 41.099 GiB, 7.32% gc time)
# 150.679085 seconds (654.56 M allocations: 72.237 GiB, 9.03% gc time)
# 240.290319 seconds (1.08 G allocations: 119.745 GiB, 9.71% gc time)
# "{\"likelihoods\":{\"pair0027\":{\"4\":{\"<\":-746.8087019182344,\"^\":-535.4526225130393,\">\":-838.5622302527338},\"2\":{\"<\":-743.3646466098199,\"^\":-741.2726117239254,\">\":-742.3815747745722},\"3\":{\"<\":-645.4043536850793,\"^\":-755.8541895395623,\">\":-810.4811909335432},\"5\":{\"<\":-771.4267683941795,\"^\":-764.4725522052803,\">\":-755.7112763265707},\"1\":{\"<\":2835.5977335021853,\"^\":2847.609819481923,\">\":2838.5115490627436}},\"pair0028\":{\"4\":{\"<\":2270.3415249684826,\"^\":2577.1658325569024,\">\":2702.3140838570444},\"2\":{\"<\":2742.6034825930724,\"^\":2764.1343871453055,\">\":2744.687641593924},\"3\":{\"<\":2570.340685266846,\"^\":2683.2816073450063,\">\":2665.7506667120842},\"5\":{\"<\":0.0,\"^\":2339.795853115411,\">\":2246.0333244575927},\"1\":{\"<\":2756.933002599709,\"^\":2842.860441259292,\">\":2760.8844626445775}},\"pair0045\":{\"4\":{\"<\":1497.1778832907949,\"^\":1833.009757168033,\">\":1525.380038784609},\"2\":{\"<\":1599.215427077149,\"^\":2203.7834408950525,\">\":1687.6525666886157},\"3\":{\"<\":1508.768732700331,\"^\":1930.2227544699715,\">\":1517.0577113528204},\"5\":{\"<\":1495.2581052384821,\"^\":1742.739454030688,\">\":1497.8626574598459},\"1\":{\"<\":1840.053916340809,\"^\":2846.2968992210053,\">\":1841.4891858901192}},\"pair0038\":{\"4\":{\"<\":1936.0397887510005,\"^\":1936.5455161616687,\">\":1933.4388046289869},\"2\":{\"<\":1976.5464128008482,\"^\":0.0,\">\":1975.416460444946},\"3\":{\"<\":1962.1432574737064,\"^\":1934.6572176683262,\">\":1928.32715207976},\"5\":{\"<\":1912.8650079810207,\"^\":1939.0222253291988,\">\":1963.2140560634964},\"1\":{\"<\":2149.6810364936678,\"^\":2154.5313353662345,\">\":2151.662659001448}},\"pair0049\":{\"4\":{\"<\":920.2576963622728,\"^\":910.5597957703787,\">\":917.1426870180525},\"2\":{\"<\":906.6745208229967,\"^\":0.0,\">\":0.0},\"3\":{\"<\":916.0142751302818,\"^\":924.91985219195,\">\":914.3494402169008},\"5\":{\"<\":928.1067237960461,\"^\":922.8752769910343,\">\":927.0762150068109},\"1\":{\"<\":919.8413973861003,\"^\":1045.497392008449,\">\":919.6499023413537}},\"pair0047\":{\"4\":{\"<\":-732.8309928961992,\"^\":-857.4827486793463,\">\":-752.6553180939986},\"2\":{\"<\":-680.0690796850818,\"^\":-682.9561558672534,\">\":-369.966770923876},\"3\":{\"<\":-843.7096987001048,\"^\":-433.8650574897051,\">\":-380.2545889886373},\"5\":{\"<\":-747.4212788661704,\"^\":-717.2042615401969,\">\":-638.2817569422886},\"1\":{\"<\":725.067936189247,\"^\":721.5113739705664,\">\":716.7740193501479}},\"pair0048\":{\"4\":{\"<\":458.8815283424598,\"^\":464.01367182019396,\">\":459.6533416925346},\"2\":{\"<\":453.6844495677358,\"^\":466.9987267024026,\">\":453.39451981563445},\"3\":{\"<\":455.40470451160803,\"^\":455.6071288067333,\">\":456.7358483480888},\"5\":{\"<\":462.09465482660687,\"^\":457.53687950495754,\">\":461.5566843923951},\"1\":{\"<\":470.57312268921845,\"^\":483.0227912963444,\">\":470.61801038450625}},\"pair0029\":{\"4\":{\"<\":726.2064678199672,\"^\":682.0265002451198,\">\":643.8859204487176},\"2\":{\"<\":773.7738116869211,\"^\":738.6524432933277,\">\":735.476381698522},\"3\":{\"<\":662.1485790410775,\"^\":693.3035309087019,\">\":647.3155561995491},\"5\":{\"<\":682.0606261995109,\"^\":605.9354646412535,\">\":681.2798271037965},\"1\":{\"<\":2787.090516748931,\"^\":2845.8282548440875,\">\":2787.0767845845335}},\"pair0034\":{\"4\":{\"<\":546.3592604502393,\"^\":566.2768184690847,\">\":445.5511434722099},\"2\":{\"<\":575.7235669161879,\"^\":530.8940226382185,\">\":531.6332777952417},\"3\":{\"<\":526.4357824069293,\"^\":522.4110419201515,\">\":550.5981962072325},\"5\":{\"<\":435.41166032211464,\"^\":407.5091788561275,\">\":349.8841015656403},\"1\":{\"<\":982.4429693533775,\"^\":984.3918582347234,\">\":976.953299773404}},\"pair0043\":{\"4\":{\"<\":4.7197026497890935,\"^\":1061.3235018231135,\">\":-2.0807776974198755},\"2\":{\"<\":90.71998060212901,\"^\":0.0,\">\":96.96414662860948},\"3\":{\"<\":264.0007936268077,\"^\":1309.0639194776215,\">\":-3.787580903874401 ...
