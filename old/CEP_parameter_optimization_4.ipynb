# %% [markdown]
# # Accuracy-based BO example

# %%
include("src/BayesianCausalityOptimization.jl");

using .BayesianCausalityOptimization

valid_pairs = setdiff(1:100,[52,53,54,55,71])
tuebingen_data = BayesianCausalityOptimization.Datasets.tuebingen(valid_pairs);
#pair_ids = ["001","007","016","025","034","049","064","072","073","078","086","087","088","096","100"]
#selected_data = create_data(tuebingen_data, pair_ids, 1000);

T_max = 10
Rs = 5:5
EPOCHS = 10
M = 2
P = 10
n_iterations = 10

optimizer, optimum = bayesian_optimization(tuebingen_data, T_max;Rs=Rs, EPOCHS=EPOCHS, M=M, P=P, 
                                            n_iterations=n_iterations)

# %% [markdown]
# # Likelihood-based BO

# %%
include("src/BayesianCausalityOptimization.jl");
include("src/BayesianCausality.jl");
include("src/Datasets.jl");
include("src/Misc.jl");

using .Misc, .BayesianCausality, .BayesianCausalityOptimization
using .Datasets
using Statistics, Distributions
using SpecialFunctions, LinearAlgebra
import Base.Iterators: product
import Random: randperm, seed!
using BayesOpt
import Base.Iterators: enumerate
import Base.Filesystem: mkpath

SEED = 100
seed!(SEED)
RESULTS_PATH = "./results/tuebingen/vb-hp-opt"
PARAMS_PATH = "./params";

# %%
valid_pairs = setdiff(1:100,[52,53,54,55,71])
tuebingen_data = BayesianCausalityOptimization.Datasets.tuebingen(valid_pairs);
# Out:
# ┌ Warning: readtable is deprecated, use CSV.read from the CSV package instead
# │   caller = ip:0x0
# └ @ Core :-1

# %%
function prepare_empty_parameter_dictionary(Rs::UnitRange{Int64}, data::Array{Dict{Symbol,Any},1})
    DIRECTION = ['>','<', '^']
    resulting_parameters = Dict()
    likelihoods = Dict()
    for (id, pair) ∈ enumerate(data)
        resulting_parameters[pair[:id]] = Dict()
        likelihoods[pair[:id]] = Dict()
        for R in Rs
            resulting_parameters[pair[:id]][R] = Dict()
            likelihoods[pair[:id]][R] = Dict()
            for direction in DIRECTION
                resulting_parameters[pair[:id]][R][direction] = Dict()
                likelihoods[pair[:id]][R][direction] = Dict()
            end
        end
    end
    return resulting_parameters, likelihoods
end

function bayesian_optimization_likelihood(xⁿ, yⁿ; R, EPOCHS, M, P, n_iterations, m₁, m₂)
    config = ConfigParameters()        # calls initialize_parameters_to_default of the C API
    config.n_iterations = n_iterations;
    config.verbose_level = 0
    set_kernel!(config, "kMaternARD5")  # calls set_kernel of the C API
    config.sc_type = SC_MAP;
    f((γ, λ₁, λ₂, a₁, a₂, b₁, b₂)) = -v_bayes([xⁿ yⁿ],R;M=M,γ=exp(γ),m₁=m₁,m₂=m₂,λ₁=exp(λ₁),λ₂=exp(λ₂),
        a₁=exp(a₁),a₂=exp(a₂),b₁=exp(b₁),b₂=exp(b₂),EPOCHS=EPOCHS)[1][end]
    param_keys = ["γ", "λ₁", "λ₂", "a₁", "a₂", "b₁", "b₂"]
    lowerbound = [log(.0001), log(.0001), log(.0001), log(.0001), log(.0001), log(.0001), log(.0001)]; 
    upperbound = [log(10000.), log(10000.), log(10000.), log(10000.), log(10000.), log(10000.), log(10000.)];
    @time optimizer, optimum = bayes_optimization(f, lowerbound, upperbound, config)
    return Dict(zip(param_keys, optimizer)), optimum
    end;
                    
function vb_hyperparameter_optimization(data,T_max=Inf; name="hp_opt_likelihood", M=1, P=1, Rs=1:1, m₁=0.0, m₂=0.0,
        EPOCHS=1, warm_start_type="free", n_iterations=200, norm=true)
    mkpath("$RESULTS_PATH/$(name)_$(warm_start_type)")
    DIRECTION = ['>','<', '^']
    parameters, likelihoods = prepare_empty_parameter_dictionary(Rs, data)
    for (id,pair) ∈ enumerate(data)
    	print(pair[:id],"...\t\t\t")
        T = length(pair[:X])
        perm = randperm(T)[1:Int(min(T,T_max))]
        x, y = pair[:X][perm], pair[:Y][perm]
        for R in Rs
            println(" ", R)
            xⁿ = norm ? (x .- mean(x)) / std(x) : x
            yⁿ = norm ? (y .- mean(y)) / std(y) : y
            parameters[pair[:id]][R]['^'], likelihoods[pair[:id]][R]['^'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=1, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
            parameters[pair[:id]][R]['>'], likelihoods[pair[:id]][R]['>'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=M, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
            parameters[pair[:id]][R]['<'], likelihoods[pair[:id]][R]['<'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=M, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
        end        
    end
    metaparameters = Dict("M"=>M, "EPOCHS"=>EPOCHS, "P"=>P, "m₁"=>m₁, "m₂"=>m₂, "T_max"=>T_max, 
        "Rs"=>Rs, "warm_start_type"=>warm_start_type, "n_iterations"=>n_iterations, 
        "SEED"=>SEED, "norm"=>norm)
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/metaparameters.json", metaparameters=metaparameters)
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/parameters.json", parameters=parameters);
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/likelihoods.json", likelihoods=likelihoods);
    end;

# %%
vb_hyperparameter_optimization(tuebingen_data[75:end],1000; name="hp_opt_likelihood_4", M=4, P=100, Rs=1:5, m₁=0.0, m₂=0.0,
        EPOCHS=200, warm_start_type="free", n_iterations=200)
# Out:
# pair0080...			 1
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:441
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:441
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:443
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:443
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:446
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:446
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:450
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:450
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:450
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:450
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:450
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:450
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:451
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:451
# ┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
# │   caller = #v_bayes#24(::Int64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Float64, ::Int64, ::typeof(v_bayes), ::Array{Float64,2}, ::Int64) at BayesianCausality.jl:452
# └ @ Main.BayesianCausality /home/melih/Desktop/projects/aistats_causality/src/BayesianCausality.jl:452
#  23.043486 seconds (6.23 M allocations: 441.569 MiB, 0.62% gc time)
#  21.973428 seconds (6.00 M allocations: 667.103 MiB, 0.82% gc time)
#  23.982096 seconds (6.00 M allocations: 667.103 MiB, 0.73% gc time)
#  2
#  76.878815 seconds (313.70 M allocations: 22.419 GiB, 7.80% gc time)
#  86.336407 seconds (272.28 M allocations: 29.524 GiB, 8.45% gc time)
# 102.715862 seconds (349.05 M allocations: 37.873 GiB, 8.10% gc time)
#  3
# 114.960742 seconds (593.35 M allocations: 42.744 GiB, 9.45% gc time)
# 242.632879 seconds (952.72 M allocations: 104.955 GiB, 11.02% gc time)
# 192.526395 seconds (746.65 M allocations: 82.161 GiB, 11.38% gc time)
#  4
# 221.962256 seconds (1.34 G allocations: 96.601 GiB, 11.23% gc time)
# 250.140579 seconds (1.01 G allocations: 110.971 GiB, 11.68% gc time)
# 314.230471 seconds (1.33 G allocations: 147.010 GiB, 11.36% gc time)
#  5
# 286.212080 seconds (1.76 G allocations: 126.883 GiB, 11.74% gc time)
# 391.157672 seconds (1.71 G allocations: 189.959 GiB, 12.66% gc time)
# 372.506648 seconds (1.59 G allocations: 175.982 GiB, 12.99% gc time)
# pair0081...			 1
#  26.460133 seconds (2.92 M allocations: 224.420 MiB, 0.20% gc time)
# - 07:19:53.036512 ERROR: nlopt failure
#   0.707431 seconds (615.24 k allocations: 68.396 MiB, 2.14% gc time)
#  21.646287 seconds (3.23 M allocations: 359.076 MiB, 0.40% gc time)
#  2
# - 07:20:41.924793 ERROR: nlopt failure
#  27.235427 seconds (81.10 M allocations: 5.950 GiB, 5.62% gc time)
#  89.423270 seconds (214.95 M allocations: 23.329 GiB, 6.70% gc time)
#  94.903829 seconds (237.65 M allocations: 25.798 GiB, 7.41% gc time)
#  3
# 106.372423 seconds (374.66 M allocations: 27.604 GiB, 6.96% gc time)
# 179.971655 seconds (550.73 M allocations: 60.626 GiB, 7.52% gc time)
# 117.457394 seconds (344.98 M allocations: 37.918 GiB, 7.28% gc time)
#  4
# 148.760983 seconds (586.16 M allocations: 43.127 GiB, 7.52% gc time)
# 234.173465 seconds (765.30 M allocations: 84.656 GiB, 8.86% gc time)
# 229.774518 seconds (736.12 M allocations: 81.376 GiB, 9.86% gc time)
#  5
# 149.061727 seconds (620.30 M allocations: 45.729 GiB, 8.36% gc time)
# 196.626028 seconds (647.13 M allocations: 71.270 GiB, 10.96% gc time)
# 204.929063 seconds (666.59 M allocations: 73.319 GiB, 10.75% gc time)
# pair0082...			 1
#  20.525519 seconds (2.92 M allocations: 224.420 MiB, 0.29% gc time)
#  21.502406 seconds (3.23 M allocations: 359.076 MiB, 0.44% gc time)
#  20.160905 seconds (3.23 M allocations: 359.076 MiB, 0.46% gc time)
#  2
#  46.026081 seconds (107.36 M allocations: 7.878 GiB, 4.49% gc time)
#  91.982303 seconds (226.33 M allocations: 24.573 GiB, 7.71% gc time)
#  84.484523 seconds (192.92 M allocations: 20.943 GiB, 7.36% gc time)
#  3
#  67.452367 seconds (178.48 M allocations: 13.149 GiB, 5.55% gc time)
# 174.184071 seconds (538.89 M allocations: 59.328 GiB, 7.49% gc time)
# 171.424026 seconds (509.17 M allocations: 56.011 GiB, 8.09% gc time)
#  4
# - 08:03:13.885747 ERROR: nlopt failure
# 102.680896 seconds (427.24 M allocations: 31.435 GiB, 8.24% gc time)
# 181.650254 seconds (575.12 M allocations: 63.380 GiB, 9.29% gc time)
# 179.819749 seconds (552.32 M allocations: 60.887 GiB, 9.67% gc time)
#  5
# 170.425885 seconds (701.40 M allocations: 51.710 GiB, 8.39% gc time)
# 307.172380 seconds (1.00 G allocations: 111.332 GiB, 11.20% gc time)
# 260.817816 seconds (837.62 M allocations: 92.476 GiB, 11.29% gc time)
# pair0083...			 1
#  24.800676 seconds (2.92 M allocations: 224.420 MiB, 0.26% gc time)
#  26.000812 seconds (3.23 M allocations: 359.076 MiB, 0.41% gc time)
#  23.085653 seconds (3.23 M allocations: 359.076 MiB, 0.42% gc time)
#  2
#  54.406748 seconds (113.63 M allocations: 8.340 GiB, 4.41% gc time)
#  69.343803 seconds (143.71 M allocations: 15.599 GiB, 6.95% gc time)
#  66.984056 seconds (133.72 M allocations: 14.510 GiB, 6.57% gc time)
#  3
#  77.828063 seconds (251.44 M allocations: 18.520 GiB, 6.47% gc time)
# 106.905282 seconds (293.92 M allocations: 32.235 GiB, 7.10% gc time)
# 119.268850 seconds (333.91 M allocations: 36.698 GiB, 7.29% gc time)
#  4
# 102.447994 seconds (405.25 M allocations: 29.810 GiB, 7.80% gc time)
# 172.412238 seconds (510.51 M allocations: 56.307 GiB, 8.78% gc time)
# 156.818486 seconds (468.80 M allocations: 51.745 GiB, 9.61% gc time)
#  5
# 141.171221 seconds (541.96 M allocations: 39.950 GiB, 8.13% gc time)
# 202.189490 seconds (630.70 M allocations: 69.398 GiB, 10.88% gc time)
# 239.162968 seconds (764.90 M allocations: 84.362 GiB, 11.10% gc time)
# pair0084...			 1
#  25.997973 seconds (7.32 M allocations: 541.813 MiB, 0.57% gc time)
#  27.378073 seconds (8.16 M allocations: 908.432 MiB, 0.97% gc time)
#  28.355740 seconds (8.16 M allocations: 908.432 MiB, 0.95% gc time)
#  2
#  94.129684 seconds (491.71 M allocations: 34.864 GiB, 10.44% gc time)
# 172.037562 seconds (668.89 M allocations: 72.606 GiB, 10.88% gc time)
# 192.103157 seconds (769.95 M allocations: 83.601 GiB, 10.51% gc time)
#  3
# 137.823052 seconds (841.13 M allocations: 60.144 GiB, 11.71% gc time)
# 246.046903 seconds (1.07 G allocations: 117.735 GiB, 12.65% gc time)
# 327.405016 seconds (1.43 G allocations: 157.482 GiB, 13.15% gc time)
#  4
# 290.383426 seconds (2.01 G allocations: 143.742 GiB, 13.33% gc time)
# 398.121015 seconds (1.84 G allocations: 203.077 GiB, 13.12% gc time)
# 470.403313 seconds (2.13 G allocations: 236.269 GiB, 14.12% gc time)
#  5
# 262.883213 seconds (1.81 G allocations: 129.675 GiB, 14.15% gc time)
# 345.324890 seconds (1.70 G allocations: 187.066 GiB, 13.01% gc time)
# 421.532518 seconds (1.98 G allocations: 219.337 GiB, 14.02% gc time)
# pair0085...			 1
#  21.707854 seconds (7.28 M allocations: 538.859 MiB, 0.70% gc time)
#  24.354904 seconds (8.12 M allocations: 903.286 MiB, 0.94% gc time)
#  22.107836 seconds (8.12 M allocations: 903.286 MiB, 0.95% gc time)
#  2
# 123.765623 seconds (680.76 M allocations: 48.269 GiB, 10.61% gc time)
# 170.770900 seconds (664.53 M allocations: 72.080 GiB, 11.28% gc time)
# 200.506494 seconds (840.51 M allocations: 91.221 GiB, 10.97% gc time)
#  3
# 168.870775 seconds (1.06 G allocations: 76.160 GiB, 11.58% gc time)
# 227.238771 seconds (981.10 M allocations: 107.902 GiB, 11.41% gc time)
# 321.307908 seconds (1.45 G allocations: 159.333 GiB, 13.27% gc time)
#  4
# 226.064459 seconds (1.51 G allocations: 107.941 GiB, 13.04% gc time)
# 393.002979 seconds (1.80 G allocations: 198.992 GiB, 13.48% gc time)
# 400.172448 seconds (1.83 G allocations: 202.738 GiB, 13.84% gc time)
#  5
# 325.878982 seconds (2.28 G allocations: 163.932 GiB, 14.43% gc time)
# 494.271199 seconds (2.28 G allocations: 253.002 GiB, 15.30% gc time)
# 479.155325 seconds (2.19 G allocations: 243.105 GiB, 15.49% gc time)
# pair0086...			 1
#  21.195070 seconds (5.01 M allocations: 374.899 MiB, 0.51% gc time)
#  22.306166 seconds (5.57 M allocations: 619.509 MiB, 0.61% gc time)
#  20.332249 seconds (5.57 M allocations: 619.509 MiB, 0.82% gc time)
#  2
# - 10:46:42.394452 ERROR: nlopt failure
#  22.379804 seconds (115.06 M allocations: 8.248 GiB, 10.75% gc time)
# - 10:49:19.912215 ERROR: nlopt failure
# 157.511330 seconds (567.39 M allocations: 61.650 GiB, 9.81% gc time)
# 127.794947 seconds (388.42 M allocations: 42.180 GiB, 8.96% gc time)
#  3
# 100.874703 seconds (469.92 M allocations: 33.921 GiB, 9.94% gc time)
# 274.464635 seconds (1.03 G allocations: 113.110 GiB, 11.90% gc time)
# 224.834154 seconds (815.08 M allocations: 89.796 GiB, 12.21% gc time)
#  4
# 169.764776 seconds (832.03 M allocations: 60.054 GiB, 11.25% gc time)
# 265.396381 seconds (1.01 G allocations: 111.023 GiB, 12.80% gc time)
# 339.733502 seconds (1.33 G allocations: 147.209 GiB, 12.34% gc time)
#  5
# 204.222742 seconds (1.15 G allocations: 83.600 GiB, 11.74% gc time)
# 261.809726 seconds (1.06 G allocations: 118.043 GiB, 12.86% gc time)
# 322.481077 seconds (1.31 G allocations: 145.457 GiB, 13.68% gc time)
# pair0087...			 1
#  25.687995 seconds (7.32 M allocations: 541.813 MiB, 0.54% gc time)
#  28.869881 seconds (8.16 M allocations: 908.432 MiB, 0.85% gc time)
#  25.478113 seconds (8.16 M allocations: 908.432 MiB, 1.02% gc time)
#  2
#  46.141652 seconds (139.18 M allocations: 9.836 GiB, 6.56% gc time)
#  61.869642 seconds (164.40 M allocations: 17.721 GiB, 8.84% gc time)
#  61.313396 seconds (167.67 M allocations: 18.075 GiB, 8.68% gc time)
#  3
# 153.079021 seconds (894.65 M allocations: 63.998 GiB, 12.07% gc time)
# 272.235614 seconds (1.15 G allocations: 126.856 GiB, 13.02% gc time)
# 263.123709 seconds (1.07 G allocations: 118.163 GiB, 13.87% gc time)
#  4
# 172.467844 seconds (1.08 G allocations: 77.007 GiB, 13.49% gc time)
# 309.183642 seconds (1.34 G allocations: 148.642 GiB, 12.92% gc time)
# 309.158279 seconds (1.36 G allocations: 150.778 GiB, 13.91% gc time)
#  5
# 257.992568 seconds (1.72 G allocations: 123.766 GiB, 14.53% gc time)
# 363.853278 seconds (1.62 G allocations: 180.757 GiB, 15.15% gc time)
# 379.826120 seconds (1.78 G allocations: 197.702 GiB, 13.45% gc time)
# pair0088...			 1
#  27.501211 seconds (2.20 M allocations: 172.432 MiB, 0.15% gc time)
#  23.351360 seconds (2.42 M allocations: 269.098 MiB, 0.25% gc time)
#  20.005143 seconds (2.42 M allocations: 269.098 MiB, 0.32% gc time)
#  2
#  49.611241 seconds (94.88 M allocations: 7.092 GiB, 3.97% gc time)
#  70.026374 seconds (142.05 M allocations: 15.415 GiB, 5.82% gc time)
#  87.511789 seconds (174.32 M allocations: 18.923 GiB, 5.86% gc time)
#  3
# 107.829792 seconds (295.04 M allocations: 22.097 GiB, 6.00% gc time)
# 128.417456 seconds (318.31 M allocations: 34.978 GiB, 6.85% gc time)
# 140.931910 seconds (355.91 M allocations: 39.092 GiB, 7.78% gc time)
#  4
# 145.171110 seconds (420.68 M allocations: 31.430 GiB, 6.46% gc time)
# 184.867471 seconds (485.22 M allocations: 53.535 GiB, 8.78% gc time)
# 232.432584 seconds (614.08 M allocations: 67.929 GiB, 9.43% gc time)
#  5
# 154.464223 seconds (506.72 M allocations: 37.905 GiB, 7.64% gc time)
# 205.276383 seconds (550.08 M allocations: 60.807 GiB, 9.21% gc time)
# - 12:42:16.883685 ERROR: nlopt failure
# 177.721128 seconds (516.96 M allocations: 57.253 GiB, 8.03% gc time)
# pair0089...			 1
#  23.409254 seconds (1.30 M allocations: 107.416 MiB, 0.13% gc time)
#  23.307854 seconds (1.41 M allocations: 156.593 MiB, 0.18% gc time)
#  23.763122 seconds (1.41 M allocations: 156.593 MiB, 0.16% gc time)
#  2
#  50.700670 seconds (63.82 M allocations: 5.022 GiB, 2.87% gc time)
#  77.989978 seconds (106.47 M allocations: 11.551 GiB, 3.70% gc time)
#  63.003690 seconds (79.75 M allocations: 8.649 GiB, 3.58% gc time)
#  3
#  60.118838 seconds (91.15 M allocations: 7.148 GiB, 3.44% gc time)
#  91.675580 seconds (152.36 M allocations: 16.691 GiB, 4.79% gc time)
# 117.418101 seconds (209.57 M allocations: 22.982 GiB, 5.11% gc time)
#  4
#  94.165434 seconds (170.89 M allocations: 13.340 GiB, 3.98% gc time)
# - 12:53:58.193407 ERROR: nlopt failure
#  75.713530 seconds (158.89 M allocations: 17.494 GiB, 6.57% gc time)
# 103.959468 seconds (183.41 M allocations: 20.026 GiB, 5.59% gc time)
#  5
# 122.948520 seconds (248.77 M allocations: 19.409 GiB, 4.85% gc time)
# 141.753064 seconds (270.41 M allocations: 29.697 GiB, 6.46% gc time)
# 110.893287 seconds (191.12 M allocations: 20.987 GiB, 5.89% gc time)
# pair0090...			 1
#  17.348137 seconds (1.27 M allocations: 104.888 MiB, 0.14% gc time)
#  23.317568 seconds (1.37 M allocations: 152.239 MiB, 0.20% gc time)
#  23.599856 seconds (1.37 M allocations: 152.239 MiB, 0.18% gc time)
#  2
#  48.973586 seconds (67.06 M allocations: 5.296 GiB, 3.19% gc time)
#  61.533328 seconds (68.98 M allocations: 7.479 GiB, 3.75% gc time)
#  71.547524 seconds (89.84 M allocations: 9.745 GiB, 4.26% gc time)
#  3
#  85.744125 seconds (139.37 M allocations: 10.966 GiB, 4.03% gc time)
# 106.751811 seconds (174.13 M allocations: 19.105 GiB, 5.64% gc time)
# 109.426149 seconds (174.38 M allocations: 19.156 GiB, 5.71% gc time)
#  4
# 102.145394 seconds (185.47 M allocations: 14.522 GiB, 4.27% gc time)
# 119.107831 seconds (211.66 M allocations: 23.130 GiB, 5.98% gc time)
# 166.817852 seconds (313.26 M allocations: 34.471 GiB, 6.06% gc time)
#  5
# 109.533578 seconds (220.74 M allocations: 17.271 GiB, 4.51% gc time)
# 125.288481 seconds (241.88 M allocations: 26.562 GiB, 6.53% gc time)
# 113.408592 seconds (201.94 M allocations: 22.144 GiB, 6.42% gc time)
# pair0091...			 1
#  21.544001 seconds (1.42 M allocations: 116.459 MiB, 0.18% gc time)
#  27.538392 seconds (1.55 M allocations: 172.211 MiB, 0.25% gc time)
# - 13:24:18.543227 ERROR: nlopt failure
#   7.072963 seconds (1.03 M allocations: 114.808 MiB, 0.46% gc time)
#  2
#  35.642692 seconds (23.64 M allocations: 1.839 GiB, 1.63% gc time)
#  43.832568 seconds (39.51 M allocations: 4.284 GiB, 3.30% gc time)
#  45.183656 seconds (41.39 M allocations: 4.488 GiB, 3.25% gc time)
#  3
#  74.675795 seconds (128.21 M allocations: 9.958 GiB, 4.14% gc time)
#  92.277543 seconds (146.60 M allocations: 16.084 GiB, 5.76% gc time)
# 142.580814 seconds (260.51 M allocations: 28.627 GiB, 6.82% gc time)
#  4
# 111.944328 seconds (233.92 M allocations: 18.090 GiB, 4.81% gc time)
# 106.787621 seconds (195.68 M allocations: 21.554 GiB, 4.80% gc time)
#  74.231565 seconds (130.24 M allocations: 14.322 GiB, 4.60% gc time)
#  5
# 114.196657 seconds (241.99 M allocations: 18.708 GiB, 4.70% gc time)
# - 13:40:12.890703 ERROR: nlopt failure
# 112.948785 seconds (257.44 M allocations: 28.517 GiB, 6.21% gc time)
# 135.893068 seconds (270.94 M allocations: 29.869 GiB, 6.00% gc time)
# pair0092...			 1
#  26.590061 seconds (1.43 M allocations: 116.949 MiB, 0.11% gc time)
#  24.038154 seconds (1.56 M allocations: 173.067 MiB, 0.17% gc time)
#  18.282863 seconds (1.56 M allocations: 173.067 MiB, 0.24% gc time)
#  2
#  40.150558 seconds (36.35 M allocations: 2.826 GiB, 1.92% gc time)
#  52.614160 seconds (65.64 M allocations: 7.118 GiB, 3.72% gc time)
#  55.162251 seconds (63.81 M allocations: 6.918 GiB, 3.44% gc time)
#  3
#  50.809388 seconds (71.60 M allocations: 5.557 GiB, 3.25% gc time)
#  70.098633 seconds (112.68 M allocations: 12.373 GiB, 4.91% gc time)
# - 13:48:43.701482 ERROR: nlopt failure
#  37.128824 seconds (70.83 M allocations: 7.776 GiB, 6.03% gc time)
#  4
#  78.186675 seconds (145.51 M allocations: 11.247 GiB, 4.32% gc time)
# - 13:50:30.646130 ERROR: nlopt failure
#  28.750510 seconds (62.83 M allocations: 6.934 GiB, 6.98% gc time)
#  98.175492 seconds (180.95 M allocations: 19.936 GiB, 6.11% gc time)
#  5
#  87.198612 seconds (166.16 M allocations: 12.838 GiB, 4.34% gc time)
# - 13:54:27.543051 ERROR: nlopt failure
#  51.508977 seconds (111.69 M allocations: 12.353 GiB, 7.40% gc time)
# - 13:55:57.446997 ERROR: nlopt failure
#  89.901552 seconds (182.26 M allocations: 20.143 GiB, 7.12% gc time)
# pair0093...			 1
#  22.275839 seconds (3.39 M allocations: 257.883 MiB, 0.34% gc time)
#  26.319994 seconds (3.75 M allocations: 417.014 MiB, 0.51% gc time)
#  22.534932 seconds (3.75 M allocations: 417.014 MiB, 0.56% gc time)
#  2
#  59.453425 seconds (135.61 M allocations: 9.865 GiB, 4.99% gc time)
# 101.682801 seconds (254.09 M allocations: 27.558 GiB, 8.65% gc time)
#  80.976016 seconds (212.06 M allocations: 22.991 GiB, 8.67% gc time)
#  3
# 111.594450 seconds (412.21 M allocations: 30.163 GiB, 8.23% gc time)
# 189.607878 seconds (579.79 M allocations: 63.766 GiB, 11.32% gc time)
# 175.701894 seconds (539.82 M allocations: 59.399 GiB, 10.83% gc time)
#  4
# 128.450244 seconds (523.65 M allocations: 38.279 GiB, 8.31% gc time)
# 217.592897 seconds (726.82 M allocations: 80.319 GiB, 9.98% gc time)
# 219.752567 seconds (704.76 M allocations: 77.853 GiB, 10.10% gc time)
#  5
# 160.528853 seconds (701.68 M allocations: 51.424 GiB, 9.67% gc time)
# 280.034552 seconds (944.27 M allocations: 104.723 GiB, 11.52% gc time)
# 252.231631 seconds (857.82 M allocations: 94.963 GiB, 10.97% gc time)
# pair0094...			 1
#  21.603669 seconds (7.32 M allocations: 541.813 MiB, 0.68% gc time)
#  30.626301 seconds (8.16 M allocations: 908.432 MiB, 0.78% gc time)
#  20.007825 seconds (8.16 M allocations: 908.432 MiB, 1.18% gc time)
#  2
# 132.096478 seconds (737.49 M allocations: 52.285 GiB, 11.51% gc time)
# 214.145688 seconds (845.63 M allocations: 91.771 GiB, 12.76% gc time)
# - 14:38:37.830367 ERROR: nlopt failure
#  93.063340 seconds (399.17 M allocations: 43.306 GiB, 12.48% gc time)
#  3
# 171.707511 seconds (1.04 G allocations: 74.060 GiB, 11.62% gc time)
# 323.851035 seconds (1.42 G allocations: 156.334 GiB, 13.21% gc time)
# 251.370175 seconds (1.05 G allocations: 115.762 GiB, 13.86% gc time)
#  4
# 231.458113 seconds (1.58 G allocations: 113.309 GiB, 13.93% gc time)
# 365.760129 seconds (1.68 G allocations: 185.366 GiB, 13.74% gc time)
# 436.189506 seconds (1.99 G allocations: 219.518 GiB, 14.74% gc time)
#  5
# 259.093138 seconds (1.70 G allocations: 122.439 GiB, 14.19% gc time)
# 452.863362 seconds (2.09 G allocations: 232.040 GiB, 15.62% gc time)
# 572.361848 seconds (2.72 G allocations: 302.535 GiB, 14.34% gc time)
# pair0095...			 1
#  22.512447 seconds (7.32 M allocations: 541.813 MiB, 0.64% gc time)
#  24.882423 seconds (8.16 M allocations: 908.432 MiB, 0.88% gc time)
#  24.665201 seconds (8.16 M allocations: 908.432 MiB, 0.91% gc time)
#  2
#  96.756411 seconds (499.15 M allocations: 35.405 GiB, 10.33% gc time)
# 143.237807 seconds (524.17 M allocations: 56.915 GiB, 10.99% gc time)
# 172.430886 seconds (672.86 M allocations: 73.085 GiB, 12.43% gc time)
#  3
# 150.854923 seconds (893.62 M allocations: 63.913 GiB, 12.96% gc time)
# 276.418912 seconds (1.23 G allocations: 135.260 GiB, 12.25% gc time)
# 265.560900 seconds (1.14 G allocations: 125.569 GiB, 12.08% gc time)
#  4
# 235.178279 seconds (1.64 G allocations: 117.418 GiB, 13.10% gc time)
# 421.463973 seconds (1.96 G allocations: 216.483 GiB, 14.86% gc time)
# 348.818156 seconds (1.55 G allocations: 171.441 GiB, 13.97% gc time)
#  5
# 259.500886 seconds (1.82 G allocations: 130.574 GiB, 13.70% gc time)
# 431.287411 seconds (2.04 G allocations: 225.437 GiB, 14.67% gc time)
# 395.909486 seconds (1.86 G allocations: 206.482 GiB, 14.68% gc time)
# pair0096...			 1
#  24.656480 seconds (7.32 M allocations: 541.813 MiB, 0.62% gc time)
# - 16:24:38.114950 ERROR: nlopt failure
#   1.361458 seconds (2.25 M allocations: 250.900 MiB, 4.94% gc time)
#  27.573404 seconds (8.16 M allocations: 908.432 MiB, 0.95% gc time)
#  2
#  64.050563 seconds (276.55 M allocations: 19.610 GiB, 8.76% gc time)
# 104.392216 seconds (367.85 M allocations: 39.916 GiB, 10.30% gc time)
# 113.761900 seconds (420.57 M allocations: 45.647 GiB, 10.67% gc time)
#  3
# 108.715715 seconds (623.77 M allocations: 44.598 GiB, 11.50% gc time)
# 303.934065 seconds (1.34 G allocations: 147.016 GiB, 13.28% gc time)
# 297.912129 seconds (1.30 G allocations: 142.805 GiB, 13.42% gc time)
#  4
# 224.257989 seconds (1.61 G allocations: 115.485 GiB, 12.36% gc time)
# 299.434148 seconds (1.42 G allocations: 157.054 GiB, 12.46% gc time)
# 437.216966 seconds (2.05 G allocations: 226.971 GiB, 13.74% gc time)
#  5
# 320.615959 seconds (2.34 G allocations: 167.983 GiB, 14.32% gc time)
# 431.005755 seconds (2.07 G allocations: 229.820 GiB, 13.82% gc time)
# 429.615985 seconds (2.09 G allocations: 231.388 GiB, 13.43% gc time)
# pair0097...			 1
#  22.711965 seconds (1.79 M allocations: 142.969 MiB, 0.17% gc time)
#  20.714147 seconds (1.96 M allocations: 218.082 MiB, 0.25% gc time)
#  22.913160 seconds (1.96 M allocations: 218.082 MiB, 0.20% gc time)
#  2
#  66.321223 seconds (130.01 M allocations: 9.888 GiB, 3.81% gc time)
#  75.163699 seconds (136.19 M allocations: 14.778 GiB, 4.49% gc time)
# - 17:21:12.265067 ERROR: nlopt failure
#  23.765266 seconds (55.70 M allocations: 6.047 GiB, 6.05% gc time)
#  3
#  88.664164 seconds (216.01 M allocations: 16.425 GiB, 4.50% gc time)
# 106.908097 seconds (238.13 M allocations: 26.049 GiB, 6.09% gc time)
#  85.046158 seconds (170.04 M allocations: 18.602 GiB, 5.67% gc time)
#  4
# 104.900536 seconds (270.94 M allocations: 20.533 GiB, 5.47% gc time)
# 123.891328 seconds (294.31 M allocations: 32.466 GiB, 6.99% gc time)
# 144.725765 seconds (331.30 M allocations: 36.049 GiB, 7.16% gc time)
#  5
# 151.979836 seconds (425.91 M allocations: 32.297 GiB, 6.15% gc time)
# 151.131753 seconds (362.73 M allocations: 40.027 GiB, 7.94% gc time)
# 161.168819 seconds (385.07 M allocations: 42.352 GiB, 7.85% gc time)
# pair0098...			 1
#  19.477538 seconds (1.04 M allocations: 88.937 MiB, 0.13% gc time)
#  24.612442 seconds (1.12 M allocations: 124.598 MiB, 0.15% gc time)
#  17.998419 seconds (1.12 M allocations: 124.598 MiB, 0.15% gc time)
#  2
# - 17:40:57.734330 ERROR: nlopt failure
#   4.913033 seconds (7.87 M allocations: 653.818 MiB, 3.56% gc time)
#  48.144217 seconds (45.76 M allocations: 4.961 GiB, 2.93% gc time)
#  49.429306 seconds (47.58 M allocations: 5.159 GiB, 3.10% gc time)
#  3
#  56.174163 seconds (63.12 M allocations: 5.092 GiB, 2.62% gc time)
#  57.280362 seconds (61.98 M allocations: 6.785 GiB, 3.33% gc time)
#  70.108242 seconds (79.45 M allocations: 8.680 GiB, 3.69% gc time)
#  4
#  77.768310 seconds (108.20 M allocations: 8.680 GiB, 3.78% gc time)
#  97.880243 seconds (129.11 M allocations: 14.003 GiB, 4.57% gc time)
# - 17:48:45.690015 ERROR: nlopt failure
#  11.134899 seconds (18.65 M allocations: 2.054 GiB, 5.65% gc time)
#  5
#  79.083372 seconds (111.64 M allocations: 8.942 GiB, 3.78% gc time)
# - 17:50:26.401002 ERROR: nlopt failure
#  21.615737 seconds (39.34 M allocations: 4.274 GiB, 6.74% gc time)
# - 17:50:49.100917 ERROR: nlopt failure
#  22.696035 seconds (40.72 M allocations: 4.469 GiB, 6.85% gc time)
# pair0099...			 1
#  24.641172 seconds (7.32 M allocations: 541.813 MiB, 0.59% gc time)
#  25.220210 seconds (8.16 M allocations: 908.432 MiB, 0.87% gc time)
#  23.285778 seconds (8.16 M allocations: 908.432 MiB, 0.96% gc time)
#  2
# 123.859654 seconds (678.06 M allocations: 48.087 GiB, 10.99% gc time)
# 163.957066 seconds (647.87 M allocations: 70.323 GiB, 11.64% gc time)
# 197.219311 seconds (774.31 M allocations: 84.074 GiB, 12.48% gc time)
#  3
# 197.515177 seconds (1.19 G allocations: 85.445 GiB, 13.49% gc time)
# 318.147069 seconds (1.37 G allocations: 150.427 GiB, 14.09% gc time)
# 288.178336 seconds (1.21 G allocations: 132.633 GiB, 12.85% gc time)
#  4
# 257.096835 seconds (1.71 G allocations: 122.228 GiB, 13.25% gc time)
# 307.383798 seconds (1.35 G allocations: 149.143 GiB, 14.30% gc time)
# 422.315141 seconds (1.94 G allocations: 214.237 GiB, 14.81% gc time)
#  5
# 354.527428 seconds (2.51 G allocations: 179.962 GiB, 14.17% gc time)
# 518.006021 seconds (2.46 G allocations: 273.436 GiB, 14.38% gc time)
# 382.046839 seconds (1.79 G allocations: 198.309 GiB, 13.77% gc time)
# pair0100...			 1
# - 18:50:54.908908 ERROR: nlopt failure
#   2.299660 seconds (806.20 k allocations: 64.149 MiB, 1.03% gc time)
#  23.559820 seconds (2.02 M allocations: 224.096 MiB, 0.23% gc time)
#  20.841512 seconds (2.02 M allocations: 224.096 MiB, 0.29% gc time)
#  2
#  46.283773 seconds (82.71 M allocations: 6.273 GiB, 3.46% gc time)
#  77.140355 seconds (141.56 M allocations: 15.363 GiB, 4.93% gc time)
#  66.318079 seconds (106.37 M allocations: 11.542 GiB, 4.53% gc time)
#  3
#  89.510812 seconds (218.88 M allocations: 16.603 GiB, 5.28% gc time)
#  83.571018 seconds (170.29 M allocations: 18.703 GiB, 5.97% gc time)
# 108.579963 seconds (237.89 M allocations: 26.139 GiB, 6.55% gc time)
#  4
#  88.901931 seconds (222.33 M allocations: 16.811 GiB, 5.45% gc time)
# 172.350040 seconds (423.35 M allocations: 46.573 GiB, 7.15% gc time)
# 120.880011 seconds (267.74 M allocations: 29.411 GiB, 6.89% gc time)
#  5
# 122.577585 seconds (349.97 M allocations: 26.486 GiB, 5.75% gc time)
# 152.286633 seconds (377.82 M allocations: 41.604 GiB, 7.14% gc time)
# 176.989295 seconds (436.27 M allocations: 48.147 GiB, 7.17% gc time)
# "{\"likelihoods\":{\"pair0087\":{\"4\":{\"<\":-923.3452665034149,\"^\":-681.7501131723368,\">\":-727.9613777799211},\"2\":{\"<\":-782.0145122615323,\"^\":-804.0204323497078,\">\":-785.6153655585455},\"3\":{\"<\":-906.7409863692563,\"^\":-966.1983174396693,\">\":-895.8859533285383},\"5\":{\"<\":-677.9431502544531,\"^\":-512.7682676519671,\">\":-702.2349412133403},\"1\":{\"<\":2810.6114180499017,\"^\":2848.396012638328,\">\":2811.033993157793}},\"pair0090\":{\"4\":{\"<\":356.1928794079062,\"^\":363.08652535802236,\">\":358.5972855673296},\"2\":{\"<\":356.1312816706932,\"^\":360.63331599250444,\">\":356.1675519032518},\"3\":{\"<\":363.03125448044136,\"^\":362.47203437487553,\">\":355.43710410824315},\"5\":{\"<\":362.0819768889029,\"^\":369.35681173508954,\">\":356.24288182755123},\"1\":{\"<\":353.3671301085472,\"^\":360.18262750607164,\">\":355.72809235661356}},\"pair0095\":{\"4\":{\"<\":2537.2028719817836,\"^\":2569.24645948879,\">\":2537.8331457526215},\"2\":{\"<\":2663.1481947818743,\"^\":2738.013757646909,\">\":2670.7171927485274},\"3\":{\"<\":2576.1696383997887,\"^\":2620.4195392388287,\">\":2573.3101612689356},\"5\":{\"<\":2549.761572501646,\"^\":2571.6045132966256,\">\":2543.535475545761},\"1\":{\"<\":2820.4048132199864,\"^\":2842.636484591925,\">\":2824.1268658058234}},\"pair0094\":{\"4\":{\"<\":2678.519779681373,\"^\":2719.808821374602,\">\":2681.5516773269537},\"2\":{\"<\":0.0,\"^\":2780.2213291248772,\">\":2751.148456662362},\"3\":{\"<\":2706.7973744622755,\"^\":2728.497390197824,\">\":2700.9768927869623},\"5\":{\"<\":2676.670965174826,\"^\":2700.877906444895,\">\":2686.541517209538},\"1\":{\"<\":2828.6348474625333,\"^\":2844.3700862109304,\">\":2832.7479534636727}},\"pair0080\":{\"4\":{\"<\":1349.4266800537725,\"^\":1309.2540489208322,\">\":1335.881205901284},\"2\":{\"<\":1384.151652360828,\"^\":1533.3578703868993,\">\":1422.0123632147793},\"3\":{\"<\":1318.130253401346,\"^\":1421.2951487153425,\">\":1325.8909060381113},\"5\":{\"<\":1336.4156465985784,\"^\":1285.6015306140744,\">\":1357.7839099564956},\"1\":{\"<\":1898.7003931613654,\"^\":2054.45726815553,\">\":1898.050414013893}},\"pair0083\":{\"4\":{\"<\":671.4498888194489,\"^\":703.6739703234512,\">\":678.9169453276572},\"2\":{\"<\":695.5176183762421,\"^\":772.5366581860411,\">\":677.3819546018548},\"3\":{\"<\":670.141660222175,\"^\":710.5691968587001,\">\":744.5023345789463},\"5\":{\"<\":685.6903576623317,\"^\":715.6816955933992,\">\":697.5173011232084},\"1\":{\"<\":788.1197905230773,\"^\":1040.9410580499525,\">\":788.1487021097292}},\"pair0088\":{\"4\":{\"<\":667.0359136730331,\"^\":664.8971880241928,\">\":671.7054216347136},\"2\":{\"<\":659.9033890129215,\"^\":666.0648577027498,\">\":660.9048296540712},\"3\":{\"<\":664.8627809663226,\"^\":662.7380818124997,\">\":668.6642869283983},\"5\":{\"<\":0.0,\"^\":680.2636058626755,\">\":672.588042870706},\"1\":{\"<\":710.6377439632738,\"^\":745.6191724568444,\">\":710.8986338091534}},\"pair0100\":{\"4\":{\"<\":546.9546619096424,\"^\":551.4133076933911,\">\":534.4879081270699},\"2\":{\"<\":525.9481483329113,\"^\":550.5807500110215,\">\":525.599581424712},\"3\":{\"<\":531.2731965914779,\"^\":536.6160272046769,\">\":530.2747338245114},\"5\":{\"<\":540.605805534842,\"^\":537.2283414448654,\">\":531.506365588654},\"1\":{\"<\":526.7924814864122,\"^\":0.0,\">\":530.4824888040934}},\"pair0084\":{\"4\":{\"<\":547.2828456971424,\"^\":1880.3644019225874,\">\":559.3030804436111},\"2\":{\"<\":544.5417877316894,\"^\":2514.2993580917673,\">\":539.8224184433499},\"3\":{\"<\":548.6481896468837,\"^\":2151.4521051496536,\">\":549.8877666967248},\"5\":{\"<\":582.7814332857265,\"^\":1692.339845474524,\">\":567.602246240227},\"1\":{\"<\":572.7806229696956,\"^\":2843.753357060419,\">\":572.8279645981617}},\"pair0099\":{\"4\":{\"<\":2729.2249711411328,\"^\":2183.2447723962614,\">\":2593.3689798954047},\"2\":{\"<\":2734.1079561170277,\"^\":2731.823254891091,\">\":2741.610006851631},\"3\":{\"<\":2731.6061962459403,\"^\":2188.299242667629,\">\":272 ...
