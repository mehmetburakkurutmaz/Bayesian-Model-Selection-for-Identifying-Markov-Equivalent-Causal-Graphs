# %% [markdown]
# # Accuracy-based BO example

# %%
include("src/BayesianCausalityOptimization.jl");

using .BayesianCausalityOptimization

valid_pairs = setdiff(1:100,[52,53,54,55,71])
tuebingen_data = BayesianCausalityOptimization.Datasets.tuebingen(valid_pairs);
#pair_ids = ["001","007","016","025","034","049","064","072","073","078","086","087","088","096","100"]
#selected_data = create_data(tuebingen_data, pair_ids, 1000);

T_max = 10
Rs = 5:5
EPOCHS = 10
M = 2
P = 10
n_iterations = 10

optimizer, optimum = bayesian_optimization(tuebingen_data, T_max;Rs=Rs, EPOCHS=EPOCHS, M=M, P=P, 
                                            n_iterations=n_iterations)

# %% [markdown]
# # Likelihood-based BO

# %%
include("src/BayesianCausalityOptimization.jl");
include("src/BayesianCausality.jl");
include("src/Datasets.jl");
include("src/Misc.jl");

using .Misc, .BayesianCausality, .BayesianCausalityOptimization
using .Datasets
using Statistics, Distributions
using SpecialFunctions, LinearAlgebra
import Base.Iterators: product
import Random: randperm, seed!
using BayesOpt
import Base.Iterators: enumerate
import Base.Filesystem: mkpath

SEED = 100
seed!(SEED)
RESULTS_PATH = "./results/tuebingen/vb-hp-opt"
PARAMS_PATH = "./params";
# Out:
# WARNING: replacing module BayesianCausalityOptimization.
# WARNING: replacing module BayesianCausality.
# WARNING: replacing module Datasets.
# WARNING: replacing module Misc.
# WARNING: using Misc.save_json in module Main conflicts with an existing identifier.
# WARNING: using BayesianCausality.v_bayes in module Main conflicts with an existing identifier.

# %%
valid_pairs = setdiff(1:100,[52,53,54,55,71])
tuebingen_data = BayesianCausalityOptimization.Datasets.tuebingen(valid_pairs);

# %%
redirect_stdout(prepare_empty_parameter_dictionary(1:5, tuebingen_data[1:3]), stdout)
# Out:
# MethodError: no method matching redirect_stdout(::Tuple{Dict{Any,Any},Dict{Any,Any}}, ::IJulia.IJuliaStdio{Base.PipeEndpoint})
# Closest candidates are:
#   redirect_stdout(!Matched::Function, ::Any) at stream.jl:979
#
# Stacktrace:
#  [1] top-level scope at In[16]:1

# %%
function prepare_empty_parameter_dictionary(Rs::UnitRange{Int64}, data::Array{Dict{Symbol,Any},1})
    DIRECTION = ['>','<', '^']
    resulting_parameters = Dict()
    likelihoods = Dict()
    for (id, pair) ∈ enumerate(data)
        resulting_parameters[pair[:id]] = Dict()
        likelihoods[pair[:id]] = Dict()
        for R in Rs
            resulting_parameters[pair[:id]][R] = Dict()
            likelihoods[pair[:id]][R] = Dict()
            for direction in DIRECTION
                resulting_parameters[pair[:id]][R][direction] = Dict()
                likelihoods[pair[:id]][R][direction] = Dict()
            end
        end
    end
    return resulting_parameters, likelihoods
end

function bayesian_optimization_likelihood(xⁿ, yⁿ; R, EPOCHS, M, P, n_iterations, m₁, m₂)
    config = ConfigParameters()        # calls initialize_parameters_to_default of the C API
    config.n_iterations = n_iterations;
    config.verbose_level = 0
    set_kernel!(config, "kMaternARD5")  # calls set_kernel of the C API
    config.sc_type = SC_MAP;
    f((γ, λ₁, λ₂, a₁, a₂, b₁, b₂)) = -v_bayes([xⁿ yⁿ],R;M=M,γ=exp(γ),m₁=m₁,m₂=m₂,λ₁=exp(λ₁),λ₂=exp(λ₂),
        a₁=exp(a₁),a₂=exp(a₂),b₁=exp(b₁),b₂=exp(b₂),EPOCHS=EPOCHS)[1][end]
    param_keys = ["γ", "λ₁", "λ₂", "a₁", "a₂", "b₁", "b₂"]
    lowerbound = [log(.0001), log(.0001), log(.0001), log(.0001), log(.0001), log(.0001), log(.0001)]; 
    upperbound = [log(10000.), log(10000.), log(10000.), log(10000.), log(10000.), log(10000.), log(10000.)];
    @time optimizer, optimum = bayes_optimization(f, lowerbound, upperbound, config)
    return Dict(zip(param_keys, optimizer)), optimum
    end;
                    
function vb_hyperparameter_optimization(data,T_max=Inf; name="hp_opt_likelihood", M=1, P=1, Rs=1:1, m₁=0.0, m₂=0.0,
        EPOCHS=1, warm_start_type="free", n_iterations=200, norm=true)
    mkpath("$RESULTS_PATH/$(name)_$(warm_start_type)")
    DIRECTION = ['>','<', '^']
    parameters, likelihoods = prepare_empty_parameter_dictionary(Rs, data)
    for (id,pair) ∈ enumerate(data)
    	print(pair[:id],"...\t\t\t")
        T = length(pair[:X])
        perm = randperm(T)[1:Int(min(T,T_max))]
        x, y = pair[:X][perm], pair[:Y][perm]
        for R in Rs
            println(" ", R)
            xⁿ = norm ? (x .- mean(x)) / std(x) : x
            yⁿ = norm ? (y .- mean(y)) / std(y) : y
            parameters[pair[:id]][R]['^'], likelihoods[pair[:id]][R]['^'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=1, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
            parameters[pair[:id]][R]['>'], likelihoods[pair[:id]][R]['>'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=M, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
            parameters[pair[:id]][R]['<'], likelihoods[pair[:id]][R]['<'] = bayesian_optimization_likelihood(xⁿ, yⁿ; 
                R=R, EPOCHS=EPOCHS, M=M, P=P, n_iterations=n_iterations, m₁=m₁, m₂=m₂)
        end        
    end
    metaparameters = Dict("M"=>M, "EPOCHS"=>EPOCHS, "P"=>P, "m₁"=>m₁, "m₂"=>m₂, "T_max"=>T_max, 
        "Rs"=>Rs, "warm_start_type"=>warm_start_type, "n_iterations"=>n_iterations, 
        "SEED"=>SEED, "norm"=>norm)
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/metaparameters.json", metaparameters=metaparameters)
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/parameters.json", parameters=parameters);
    save_json("$RESULTS_PATH/$(name)_$(warm_start_type)/likelihoods.json", likelihoods=likelihoods);
    end;

# %%
vb_hyperparameter_optimization(tuebingen_data[1:25],1000; name="hp_opt_likelihood_1", M=4, P=100, Rs=1:5, m₁=0.0, m₂=0.0,
        EPOCHS=200, warm_start_type="free", n_iterations=200)
# Out:
# pair0001...			 1
#  19.049168 seconds (2.82 M allocations: 216.550 MiB, 0.29% gc time)
#  18.866863 seconds (3.11 M allocations: 345.233 MiB, 0.40% gc time)
#  19.776758 seconds (3.11 M allocations: 345.233 MiB, 0.36% gc time)
#  2
#  41.293155 seconds (106.51 M allocations: 7.833 GiB, 4.46% gc time)
#  68.965048 seconds (197.27 M allocations: 21.418 GiB, 7.06% gc time)
#  55.865412 seconds (150.30 M allocations: 16.311 GiB, 6.74% gc time)
#  3
#  69.089245 seconds (266.54 M allocations: 19.669 GiB, 7.11% gc time)
#  99.556117 seconds (333.19 M allocations: 36.650 GiB, 9.03% gc time)
#  96.064717 seconds (314.37 M allocations: 34.565 GiB, 9.26% gc time)
#  4
#  64.247158 seconds (249.44 M allocations: 18.376 GiB, 7.35% gc time)
# 133.824074 seconds (500.14 M allocations: 55.249 GiB, 8.36% gc time)
# 134.583520 seconds (497.00 M allocations: 54.885 GiB, 9.04% gc time)
#  5
#  83.238684 seconds (379.23 M allocations: 28.008 GiB, 7.73% gc time)
# 200.054366 seconds (725.32 M allocations: 80.422 GiB, 10.30% gc time)
# 258.423023 seconds (822.78 M allocations: 91.457 GiB, 9.91% gc time)
# pair0002...			 1
#  20.982008 seconds (2.81 M allocations: 216.422 MiB, 0.30% gc time)
#  28.567581 seconds (3.11 M allocations: 345.233 MiB, 0.37% gc time)
#  22.769553 seconds (3.11 M allocations: 345.233 MiB, 0.46% gc time)
#  2
#  44.704933 seconds (85.71 M allocations: 6.306 GiB, 3.81% gc time)
#  67.843949 seconds (128.29 M allocations: 13.926 GiB, 6.04% gc time)
#  62.751681 seconds (119.25 M allocations: 12.942 GiB, 5.92% gc time)
#  3
#  67.975141 seconds (194.97 M allocations: 14.390 GiB, 6.56% gc time)
# 105.496947 seconds (245.06 M allocations: 26.943 GiB, 8.09% gc time)
# 107.467990 seconds (273.36 M allocations: 30.021 GiB, 9.24% gc time)
#  4
#  93.144530 seconds (294.38 M allocations: 21.695 GiB, 7.11% gc time)
# 186.127127 seconds (547.08 M allocations: 60.467 GiB, 9.86% gc time)
# - 06:51:59.482366 ERROR: nlopt failure
#  56.275278 seconds (185.01 M allocations: 20.430 GiB, 11.70% gc time)
#  5
# 115.688191 seconds (422.61 M allocations: 31.207 GiB, 7.89% gc time)
# 163.624911 seconds (498.38 M allocations: 55.130 GiB, 8.82% gc time)
# 189.428715 seconds (582.91 M allocations: 64.427 GiB, 9.73% gc time)
# pair0003...			 1
#  22.982267 seconds (2.81 M allocations: 216.422 MiB, 0.27% gc time)
#  23.688103 seconds (3.11 M allocations: 345.233 MiB, 0.36% gc time)
# - 07:00:51.594347 ERROR: nlopt failure
#  16.698094 seconds (2.90 M allocations: 322.218 MiB, 0.54% gc time)
#  2
#  73.073596 seconds (193.12 M allocations: 14.205 GiB, 5.64% gc time)
# 104.123851 seconds (239.55 M allocations: 26.007 GiB, 7.32% gc time)
#  95.538012 seconds (212.72 M allocations: 23.092 GiB, 7.01% gc time)
#  3
# 107.851013 seconds (357.00 M allocations: 26.358 GiB, 6.97% gc time)
# 125.636075 seconds (338.54 M allocations: 37.151 GiB, 8.78% gc time)
# 157.718497 seconds (437.59 M allocations: 48.173 GiB, 9.27% gc time)
#  4
# 115.820140 seconds (414.53 M allocations: 30.551 GiB, 8.12% gc time)
# 194.946489 seconds (576.85 M allocations: 63.705 GiB, 10.68% gc time)
# - 07:19:39.120790 ERROR: nlopt failure
# 152.815542 seconds (463.84 M allocations: 51.219 GiB, 11.06% gc time)
#  5
# 131.725408 seconds (520.39 M allocations: 38.431 GiB, 8.08% gc time)
# 202.000839 seconds (613.27 M allocations: 67.809 GiB, 8.33% gc time)
# 201.131156 seconds (649.79 M allocations: 71.884 GiB, 9.21% gc time)
# pair0004...			 1
#  22.971737 seconds (2.81 M allocations: 216.422 MiB, 0.23% gc time)
#  19.820804 seconds (3.11 M allocations: 345.233 MiB, 0.45% gc time)
#  22.663221 seconds (3.11 M allocations: 345.233 MiB, 0.40% gc time)
#  2
#  52.531199 seconds (137.68 M allocations: 10.123 GiB, 4.95% gc time)
# 102.455695 seconds (251.19 M allocations: 27.271 GiB, 6.91% gc time)
#  86.575477 seconds (195.10 M allocations: 21.172 GiB, 6.59% gc time)
#  3
# 100.364523 seconds (333.17 M allocations: 24.587 GiB, 6.42% gc time)
# 126.528385 seconds (356.32 M allocations: 39.173 GiB, 8.39% gc time)
# 116.047702 seconds (296.06 M allocations: 32.544 GiB, 8.28% gc time)
#  4
# - 07:40:55.847505 ERROR: nlopt failure
#  91.906096 seconds (373.02 M allocations: 27.498 GiB, 8.45% gc time)
# 187.267669 seconds (551.80 M allocations: 60.977 GiB, 9.88% gc time)
# - 07:45:43.938796 ERROR: nlopt failure
# 100.823128 seconds (326.97 M allocations: 36.159 GiB, 11.52% gc time)
#  5
# 150.426061 seconds (573.19 M allocations: 42.331 GiB, 8.33% gc time)
# 287.108844 seconds (948.42 M allocations: 105.336 GiB, 9.77% gc time)
# 211.889710 seconds (683.18 M allocations: 75.774 GiB, 8.90% gc time)
# pair0005...			 1
#  22.589276 seconds (7.32 M allocations: 541.813 MiB, 0.58% gc time)
#  26.132013 seconds (8.16 M allocations: 908.432 MiB, 0.85% gc time)
#  22.161212 seconds (8.16 M allocations: 908.432 MiB, 0.92% gc time)
#  2
#  86.376456 seconds (460.91 M allocations: 32.693 GiB, 9.74% gc time)
# 145.221829 seconds (573.98 M allocations: 62.327 GiB, 11.32% gc time)
# - 08:03:48.858009 ERROR: nlopt failure
# 132.756888 seconds (547.92 M allocations: 59.515 GiB, 12.26% gc time)
#  3
# 145.961846 seconds (885.20 M allocations: 63.330 GiB, 12.34% gc time)
# 287.590243 seconds (1.28 G allocations: 140.842 GiB, 13.13% gc time)
# 256.110815 seconds (1.12 G allocations: 123.711 GiB, 12.48% gc time)
#  4
# 224.637801 seconds (1.54 G allocations: 110.426 GiB, 13.34% gc time)
# 385.904307 seconds (1.78 G allocations: 196.387 GiB, 13.97% gc time)
# 406.420534 seconds (1.89 G allocations: 208.147 GiB, 13.97% gc time)
#  5
# 252.671712 seconds (1.77 G allocations: 126.805 GiB, 13.25% gc time)
# 462.601039 seconds (2.22 G allocations: 246.199 GiB, 13.71% gc time)
# 461.204295 seconds (2.19 G allocations: 241.051 GiB, 14.14% gc time)
# pair0006...			 1
#  25.549123 seconds (7.39 M allocations: 546.974 MiB, 0.55% gc time)
#  25.836884 seconds (8.16 M allocations: 908.432 MiB, 0.86% gc time)
#  24.234735 seconds (8.16 M allocations: 908.432 MiB, 0.88% gc time)
#  2
#  82.897163 seconds (408.42 M allocations: 28.957 GiB, 9.28% gc time)
# 204.415741 seconds (804.13 M allocations: 87.330 GiB, 11.71% gc time)
# 280.123856 seconds (1.14 G allocations: 123.993 GiB, 11.65% gc time)
#  3
# 177.766807 seconds (1.09 G allocations: 78.267 GiB, 12.57% gc time)
# 273.709051 seconds (1.18 G allocations: 129.486 GiB, 13.27% gc time)
# 388.384068 seconds (1.68 G allocations: 184.951 GiB, 14.06% gc time)
#  4
# 208.426116 seconds (1.37 G allocations: 98.090 GiB, 13.50% gc time)
# 403.735523 seconds (1.83 G allocations: 201.854 GiB, 13.31% gc time)
# 384.963540 seconds (1.76 G allocations: 194.520 GiB, 13.99% gc time)
#  5
# 288.236338 seconds (2.02 G allocations: 145.443 GiB, 13.73% gc time)
# 483.760037 seconds (2.23 G allocations: 246.645 GiB, 15.35% gc time)
# 409.615166 seconds (1.92 G allocations: 212.083 GiB, 14.33% gc time)
# pair0007...			 1
#  24.451705 seconds (7.32 M allocations: 541.813 MiB, 0.52% gc time)
#  22.230570 seconds (8.16 M allocations: 908.432 MiB, 0.93% gc time)
#  24.720019 seconds (8.16 M allocations: 908.432 MiB, 0.84% gc time)
#  2
#  77.317473 seconds (404.88 M allocations: 28.716 GiB, 9.74% gc time)
# 161.354392 seconds (647.55 M allocations: 70.326 GiB, 11.41% gc time)
# 181.671043 seconds (675.98 M allocations: 73.420 GiB, 11.15% gc time)
#  3
# 143.820585 seconds (865.77 M allocations: 61.933 GiB, 12.54% gc time)
# 288.583528 seconds (1.25 G allocations: 137.094 GiB, 12.98% gc time)
# 277.465675 seconds (1.16 G allocations: 127.299 GiB, 12.48% gc time)
#  4
# 226.031628 seconds (1.50 G allocations: 107.620 GiB, 13.39% gc time)
# 423.405103 seconds (1.87 G allocations: 206.059 GiB, 15.43% gc time)
# 344.104111 seconds (1.48 G allocations: 163.255 GiB, 15.17% gc time)
#  5
# 283.768338 seconds (1.92 G allocations: 137.642 GiB, 14.62% gc time)
# 475.063337 seconds (2.16 G allocations: 239.404 GiB, 15.41% gc time)
# 371.807708 seconds (1.70 G allocations: 186.761 GiB, 15.15% gc time)
# pair0008...			 1
#  19.478229 seconds (7.32 M allocations: 541.813 MiB, 0.78% gc time)
#  24.799862 seconds (8.16 M allocations: 908.432 MiB, 0.96% gc time)
#  22.810732 seconds (8.16 M allocations: 908.432 MiB, 1.08% gc time)
#  2
#  98.174890 seconds (482.98 M allocations: 34.256 GiB, 10.51% gc time)
# 188.528846 seconds (693.90 M allocations: 75.366 GiB, 11.93% gc time)
# 178.504514 seconds (666.68 M allocations: 72.406 GiB, 11.67% gc time)
#  3
# 189.887586 seconds (1.16 G allocations: 82.740 GiB, 13.47% gc time)
# 395.640439 seconds (1.68 G allocations: 184.640 GiB, 14.35% gc time)
# 387.900199 seconds (1.61 G allocations: 177.760 GiB, 15.19% gc time)
#  4
# 204.113756 seconds (1.33 G allocations: 95.203 GiB, 14.04% gc time)
# 389.153108 seconds (1.78 G allocations: 196.909 GiB, 13.75% gc time)
# 384.509609 seconds (1.74 G allocations: 192.315 GiB, 14.49% gc time)
#  5
# 286.779394 seconds (1.94 G allocations: 139.077 GiB, 14.76% gc time)
# 529.850277 seconds (2.40 G allocations: 265.669 GiB, 16.61% gc time)
# 455.327746 seconds (2.06 G allocations: 229.506 GiB, 14.86% gc time)
# pair0009...			 1
#  21.808342 seconds (7.32 M allocations: 541.813 MiB, 0.71% gc time)
#  21.838583 seconds (8.16 M allocations: 908.432 MiB, 1.14% gc time)
#  27.046685 seconds (8.16 M allocations: 908.432 MiB, 0.97% gc time)
#  2
#  93.491170 seconds (463.10 M allocations: 32.836 GiB, 11.04% gc time)
# 207.033342 seconds (780.46 M allocations: 84.752 GiB, 12.39% gc time)
# 304.339674 seconds (1.18 G allocations: 127.884 GiB, 13.32% gc time)
#  3
# 157.880747 seconds (894.48 M allocations: 63.991 GiB, 14.11% gc time)
# 314.455262 seconds (1.33 G allocations: 146.916 GiB, 13.44% gc time)
# 251.597314 seconds (1.09 G allocations: 119.710 GiB, 13.16% gc time)
#  4
# 204.334883 seconds (1.43 G allocations: 102.345 GiB, 13.33% gc time)
# 346.541371 seconds (1.59 G allocations: 175.226 GiB, 14.13% gc time)
# 449.379318 seconds (2.08 G allocations: 229.895 GiB, 14.00% gc time)
#  5
# 260.289579 seconds (1.81 G allocations: 130.253 GiB, 13.80% gc time)
# 380.805920 seconds (1.79 G allocations: 198.203 GiB, 13.93% gc time)
# 430.020473 seconds (2.09 G allocations: 231.798 GiB, 14.10% gc time)
# pair0010...			 1
#  23.548538 seconds (7.32 M allocations: 541.813 MiB, 0.58% gc time)
#  28.521482 seconds (8.16 M allocations: 908.432 MiB, 0.82% gc time)
#  23.582948 seconds (8.16 M allocations: 908.432 MiB, 0.95% gc time)
#  2
#  83.201004 seconds (425.97 M allocations: 30.201 GiB, 9.41% gc time)
# 183.108900 seconds (755.49 M allocations: 82.032 GiB, 11.33% gc time)
# 168.302493 seconds (672.96 M allocations: 73.060 GiB, 11.05% gc time)
#  3
# 141.224910 seconds (868.14 M allocations: 62.095 GiB, 11.92% gc time)
# 251.092582 seconds (1.12 G allocations: 122.684 GiB, 13.28% gc time)
# 255.055255 seconds (1.10 G allocations: 120.637 GiB, 13.53% gc time)
#  4
# - 13:09:43.557074 ERROR: nlopt failure
# 100.141968 seconds (734.64 M allocations: 52.578 GiB, 14.29% gc time)
# 357.285388 seconds (1.66 G allocations: 183.616 GiB, 12.37% gc time)
# 340.626465 seconds (1.64 G allocations: 180.465 GiB, 12.91% gc time)
#  5
# 276.838656 seconds (1.97 G allocations: 141.576 GiB, 13.36% gc time)
# 411.741823 seconds (1.93 G allocations: 213.989 GiB, 14.54% gc time)
# - 13:38:29.556732 ERROR: nlopt failure
# 339.505926 seconds (1.68 G allocations: 185.894 GiB, 12.86% gc time)
# pair0011...			 1
#  23.004609 seconds (7.32 M allocations: 541.813 MiB, 0.54% gc time)
#  21.286615 seconds (8.16 M allocations: 908.432 MiB, 0.96% gc time)
#  23.547091 seconds (8.16 M allocations: 908.432 MiB, 0.87% gc time)
#  2
#  72.758639 seconds (355.99 M allocations: 25.241 GiB, 8.47% gc time)
# 185.342322 seconds (781.23 M allocations: 84.852 GiB, 11.13% gc time)
# - 13:47:21.403083 ERROR: nlopt failure
# 205.905133 seconds (876.51 M allocations: 95.218 GiB, 11.87% gc time)
#  3
# 150.455094 seconds (965.00 M allocations: 69.030 GiB, 12.39% gc time)
# 281.496038 seconds (1.25 G allocations: 137.498 GiB, 12.20% gc time)
# 293.820799 seconds (1.30 G allocations: 142.715 GiB, 13.18% gc time)
#  4
# 209.683227 seconds (1.44 G allocations: 103.282 GiB, 12.76% gc time)
# 533.375342 seconds (2.44 G allocations: 270.106 GiB, 14.99% gc time)
# 361.156587 seconds (1.61 G allocations: 178.314 GiB, 14.62% gc time)
#  5
# 235.400564 seconds (1.58 G allocations: 113.149 GiB, 13.28% gc time)
# 559.836899 seconds (2.65 G allocations: 294.844 GiB, 14.04% gc time)
# 442.577212 seconds (2.05 G allocations: 226.993 GiB, 15.21% gc time)
# pair0012...			 1
# - 14:38:46.787409 ERROR: nlopt failure
#  17.578548 seconds (7.18 M allocations: 531.493 MiB, 0.85% gc time)
#  23.013500 seconds (8.16 M allocations: 908.432 MiB, 1.18% gc time)
#  25.927946 seconds (8.16 M allocations: 908.432 MiB, 1.02% gc time)
#  2
# 101.311812 seconds (535.56 M allocations: 37.992 GiB, 10.83% gc time)
# 180.438306 seconds (685.11 M allocations: 74.427 GiB, 11.96% gc time)
# 174.313053 seconds (664.43 M allocations: 72.173 GiB, 11.76% gc time)
#  3
# 145.268432 seconds (844.75 M allocations: 60.428 GiB, 12.61% gc time)
# 281.447484 seconds (1.20 G allocations: 131.554 GiB, 13.75% gc time)
# 322.401035 seconds (1.36 G allocations: 149.737 GiB, 14.53% gc time)
#  4
# 263.190032 seconds (1.75 G allocations: 125.299 GiB, 14.22% gc time)
# 410.375417 seconds (1.79 G allocations: 197.784 GiB, 14.68% gc time)
# 513.989166 seconds (2.27 G allocations: 251.107 GiB, 15.09% gc time)
#  5
# 281.594647 seconds (1.90 G allocations: 136.482 GiB, 14.05% gc time)
# 589.680900 seconds (2.73 G allocations: 303.836 GiB, 14.94% gc time)
# 473.520993 seconds (2.20 G allocations: 244.349 GiB, 14.94% gc time)
# pair0013...			 1
#  24.918963 seconds (3.17 M allocations: 242.419 MiB, 0.26% gc time)
# - 15:42:29.906678 ERROR: nlopt failure
#  11.721677 seconds (3.01 M allocations: 335.061 MiB, 0.68% gc time)
#  26.614867 seconds (3.44 M allocations: 382.407 MiB, 0.40% gc time)
#  2
#  41.523034 seconds (76.18 M allocations: 5.573 GiB, 3.84% gc time)
#  64.725500 seconds (139.17 M allocations: 15.112 GiB, 6.80% gc time)
#  62.575593 seconds (116.71 M allocations: 12.671 GiB, 5.94% gc time)
#  3
#  77.483916 seconds (223.01 M allocations: 16.382 GiB, 6.48% gc time)
# 108.194221 seconds (301.56 M allocations: 33.168 GiB, 9.34% gc time)
# 108.478724 seconds (296.91 M allocations: 32.560 GiB, 9.30% gc time)
#  4
# 113.394997 seconds (409.49 M allocations: 30.045 GiB, 8.41% gc time)
# 170.006856 seconds (505.38 M allocations: 55.747 GiB, 10.47% gc time)
# 177.294668 seconds (529.49 M allocations: 58.473 GiB, 11.02% gc time)
#  5
# 170.111028 seconds (682.85 M allocations: 50.214 GiB, 8.88% gc time)
# 192.490807 seconds (610.36 M allocations: 67.430 GiB, 10.42% gc time)
# 201.259689 seconds (655.02 M allocations: 72.308 GiB, 10.69% gc time)
# pair0014...			 1
#  26.648743 seconds (3.11 M allocations: 237.888 MiB, 0.22% gc time)
#  22.769390 seconds (3.44 M allocations: 382.407 MiB, 0.53% gc time)
#  21.097600 seconds (3.44 M allocations: 382.407 MiB, 0.44% gc time)
#  2
#  44.662555 seconds (106.91 M allocations: 7.816 GiB, 5.53% gc time)
#  57.300757 seconds (110.59 M allocations: 11.983 GiB, 6.25% gc time)
#  62.983056 seconds (124.22 M allocations: 13.469 GiB, 6.85% gc time)
#  3
#  62.998902 seconds (184.30 M allocations: 13.536 GiB, 7.13% gc time)
# 177.081872 seconds (490.19 M allocations: 53.882 GiB, 10.19% gc time)
# 124.418168 seconds (341.68 M allocations: 37.547 GiB, 10.13% gc time)
#  4
# 140.600486 seconds (519.04 M allocations: 38.088 GiB, 8.99% gc time)
# 162.589576 seconds (476.64 M allocations: 52.506 GiB, 11.45% gc time)
# 297.712969 seconds (925.35 M allocations: 102.452 GiB, 11.80% gc time)
#  5
# 165.156946 seconds (675.98 M allocations: 49.708 GiB, 9.25% gc time)
# 258.800071 seconds (833.83 M allocations: 92.317 GiB, 10.75% gc time)
# 200.026076 seconds (645.44 M allocations: 71.211 GiB, 10.28% gc time)
# pair0015...			 1
#  24.731790 seconds (3.15 M allocations: 241.286 MiB, 0.30% gc time)
#  21.558212 seconds (3.44 M allocations: 382.407 MiB, 0.45% gc time)
#  20.438530 seconds (3.44 M allocations: 382.407 MiB, 0.54% gc time)
#  2
#  49.396956 seconds (112.52 M allocations: 8.232 GiB, 5.03% gc time)
# 105.000488 seconds (252.82 M allocations: 27.458 GiB, 7.73% gc time)
# - 16:43:13.160957 ERROR: nlopt failure
#  83.114192 seconds (235.04 M allocations: 25.532 GiB, 8.08% gc time)
#  3
#  77.475915 seconds (249.31 M allocations: 18.311 GiB, 6.66% gc time)
# 146.402554 seconds (420.15 M allocations: 46.082 GiB, 9.06% gc time)
# 128.579145 seconds (366.10 M allocations: 40.154 GiB, 9.44% gc time)
#  4
# 101.999210 seconds (364.14 M allocations: 26.713 GiB, 7.75% gc time)
# 184.377535 seconds (537.43 M allocations: 59.105 GiB, 10.47% gc time)
# 228.831541 seconds (702.95 M allocations: 77.605 GiB, 11.22% gc time)
#  5
# - 16:58:15.824068 ERROR: nlopt failure
#  34.994703 seconds (166.71 M allocations: 12.259 GiB, 11.04% gc time)
# 276.260167 seconds (930.41 M allocations: 103.356 GiB, 10.18% gc time)
# 326.661446 seconds (1.09 G allocations: 121.032 GiB, 10.35% gc time)
# pair0016...			 1
#  26.281568 seconds (3.11 M allocations: 237.888 MiB, 0.23% gc time)
#  24.575796 seconds (3.44 M allocations: 382.407 MiB, 0.39% gc time)
#  26.202591 seconds (3.44 M allocations: 382.407 MiB, 0.37% gc time)
#  2
#  53.423405 seconds (120.09 M allocations: 8.783 GiB, 4.62% gc time)
#  79.185486 seconds (182.55 M allocations: 19.812 GiB, 7.15% gc time)
#  74.454241 seconds (178.61 M allocations: 19.382 GiB, 7.51% gc time)
#  3
# 117.288182 seconds (418.56 M allocations: 30.749 GiB, 7.65% gc time)
# 153.258946 seconds (442.89 M allocations: 48.687 GiB, 9.70% gc time)
# 136.486959 seconds (416.50 M allocations: 45.697 GiB, 9.11% gc time)
#  4
# 117.961614 seconds (456.85 M allocations: 33.520 GiB, 7.47% gc time)
# 212.465953 seconds (710.04 M allocations: 78.357 GiB, 10.55% gc time)
# 181.079131 seconds (581.29 M allocations: 64.018 GiB, 10.73% gc time)
#  5
# 157.675918 seconds (659.72 M allocations: 48.507 GiB, 8.73% gc time)
# 255.298084 seconds (852.26 M allocations: 94.343 GiB, 10.36% gc time)
# 224.830104 seconds (760.82 M allocations: 83.741 GiB, 10.15% gc time)
# pair0017...			 1
#  24.481122 seconds (7.32 M allocations: 541.813 MiB, 0.55% gc time)
#  24.923453 seconds (8.16 M allocations: 908.432 MiB, 1.02% gc time)
#  21.426529 seconds (8.16 M allocations: 908.432 MiB, 0.99% gc time)
#  2
#  51.113093 seconds (203.74 M allocations: 14.449 GiB, 6.93% gc time)
#  74.583671 seconds (258.45 M allocations: 28.039 GiB, 9.78% gc time)
#  84.008327 seconds (281.77 M allocations: 30.582 GiB, 9.42% gc time)
#  3
# 106.284288 seconds (615.37 M allocations: 44.014 GiB, 11.20% gc time)
# 231.637327 seconds (1.00 G allocations: 110.397 GiB, 12.61% gc time)
# 181.793748 seconds (746.92 M allocations: 82.223 GiB, 12.42% gc time)
#  4
# 157.852091 seconds (992.58 M allocations: 71.053 GiB, 13.31% gc time)
# 282.447612 seconds (1.20 G allocations: 132.509 GiB, 15.33% gc time)
# 286.768726 seconds (1.22 G allocations: 134.058 GiB, 15.67% gc time)
#  5
# 253.768256 seconds (1.69 G allocations: 121.381 GiB, 14.74% gc time)
# 406.497443 seconds (1.81 G allocations: 200.691 GiB, 15.27% gc time)
# 426.095780 seconds (1.94 G allocations: 215.504 GiB, 15.29% gc time)
# pair0018...			 1
# - 18:22:39.044223 ERROR: nlopt failure
#   6.137748 seconds (1.36 M allocations: 105.155 MiB, 0.57% gc time)
# - 18:22:52.074380 ERROR: nlopt failure
#  13.029663 seconds (2.31 M allocations: 256.474 MiB, 0.63% gc time)
#  26.366957 seconds (2.83 M allocations: 314.968 MiB, 0.29% gc time)
#  2
#  53.628580 seconds (99.39 M allocations: 7.348 GiB, 4.34% gc time)
#  72.104646 seconds (138.23 M allocations: 14.995 GiB, 6.46% gc time)
#  68.436928 seconds (130.18 M allocations: 14.119 GiB, 6.49% gc time)
#  3
#  84.213768 seconds (228.01 M allocations: 16.911 GiB, 6.81% gc time)
# 126.690400 seconds (304.68 M allocations: 33.400 GiB, 8.43% gc time)
# 169.042569 seconds (430.76 M allocations: 47.361 GiB, 8.22% gc time)
#  4
# 127.299934 seconds (412.45 M allocations: 30.539 GiB, 7.83% gc time)
# 188.391644 seconds (499.64 M allocations: 55.182 GiB, 9.72% gc time)
# - 18:40:24.367971 ERROR: nlopt failure
# 136.114269 seconds (382.82 M allocations: 42.290 GiB, 10.66% gc time)
#  5
# 168.686219 seconds (611.92 M allocations: 45.394 GiB, 8.51% gc time)
# 200.762043 seconds (558.18 M allocations: 61.803 GiB, 10.61% gc time)
# 232.067212 seconds (654.63 M allocations: 72.665 GiB, 10.73% gc time)
# pair0019...			 1
#  22.019222 seconds (1.74 M allocations: 138.880 MiB, 0.19% gc time)
#  20.504181 seconds (1.90 M allocations: 211.070 MiB, 0.31% gc time)
#  23.191485 seconds (1.90 M allocations: 211.070 MiB, 0.25% gc time)
#  2
#  28.230359 seconds (14.99 M allocations: 1.144 GiB, 1.16% gc time)
#  35.232332 seconds (32.72 M allocations: 3.550 GiB, 2.95% gc time)
#  29.690615 seconds (21.49 M allocations: 2.329 GiB, 2.39% gc time)
#  3
#  79.349283 seconds (158.14 M allocations: 12.057 GiB, 4.62% gc time)
#  72.759193 seconds (130.87 M allocations: 14.375 GiB, 6.27% gc time)
#  73.959031 seconds (136.27 M allocations: 14.963 GiB, 6.61% gc time)
#  4
#  99.148818 seconds (235.22 M allocations: 17.871 GiB, 5.68% gc time)
# 105.729067 seconds (209.33 M allocations: 23.054 GiB, 7.08% gc time)
#  93.706042 seconds (186.56 M allocations: 20.581 GiB, 6.86% gc time)
#  5
# 115.025520 seconds (298.20 M allocations: 22.667 GiB, 5.86% gc time)
# 122.827874 seconds (259.05 M allocations: 28.739 GiB, 7.78% gc time)
# - 19:06:12.106750 ERROR: nlopt failure
#  24.828108 seconds (65.65 M allocations: 7.235 GiB, 10.15% gc time)
# pair0020...			 1
#  25.921604 seconds (2.81 M allocations: 216.422 MiB, 0.24% gc time)
#  20.442009 seconds (3.11 M allocations: 345.233 MiB, 0.42% gc time)
#  21.763502 seconds (3.11 M allocations: 345.233 MiB, 0.38% gc time)
#  2
#  57.913533 seconds (137.88 M allocations: 10.139 GiB, 4.67% gc time)
#  68.635643 seconds (160.68 M allocations: 17.435 GiB, 6.86% gc time)
#  62.266865 seconds (123.02 M allocations: 13.342 GiB, 5.86% gc time)
#  3
#  88.095801 seconds (262.84 M allocations: 19.400 GiB, 6.49% gc time)
# 115.496854 seconds (310.46 M allocations: 34.120 GiB, 8.14% gc time)
#  95.263874 seconds (278.94 M allocations: 30.652 GiB, 8.64% gc time)
#  4
# 116.088732 seconds (462.86 M allocations: 34.115 GiB, 8.13% gc time)
# 158.981269 seconds (499.36 M allocations: 55.039 GiB, 10.30% gc time)
# 182.738488 seconds (581.10 M allocations: 64.325 GiB, 10.91% gc time)
#  5
# 132.254775 seconds (552.79 M allocations: 40.823 GiB, 8.46% gc time)
# 184.673041 seconds (614.15 M allocations: 68.016 GiB, 11.20% gc time)
# 206.624468 seconds (697.46 M allocations: 77.137 GiB, 11.70% gc time)
# pair0021...			 1
#  21.443897 seconds (2.81 M allocations: 216.422 MiB, 0.28% gc time)
#  21.961659 seconds (3.12 M allocations: 346.877 MiB, 0.46% gc time)
#  23.635545 seconds (3.11 M allocations: 345.233 MiB, 0.44% gc time)
#  2
#  54.565437 seconds (153.27 M allocations: 11.273 GiB, 5.81% gc time)
#  66.141041 seconds (163.65 M allocations: 17.759 GiB, 7.56% gc time)
#  55.950403 seconds (127.11 M allocations: 13.785 GiB, 5.95% gc time)
#  3
#  81.879791 seconds (286.82 M allocations: 21.181 GiB, 6.98% gc time)
# 116.680751 seconds (335.46 M allocations: 36.940 GiB, 8.16% gc time)
# 114.599761 seconds (348.70 M allocations: 38.331 GiB, 8.93% gc time)
#  4
# 109.355949 seconds (450.35 M allocations: 33.195 GiB, 7.79% gc time)
# 205.309902 seconds (691.79 M allocations: 76.462 GiB, 10.28% gc time)
# 238.708788 seconds (803.87 M allocations: 88.752 GiB, 10.82% gc time)
#  5
# 144.353228 seconds (621.72 M allocations: 45.917 GiB, 8.77% gc time)
# 181.200809 seconds (589.94 M allocations: 64.928 GiB, 11.41% gc time)
# 283.580249 seconds (962.77 M allocations: 107.057 GiB, 12.03% gc time)
# pair0022...			 1
#  24.234876 seconds (3.51 M allocations: 266.925 MiB, 0.31% gc time)
#  20.169490 seconds (3.89 M allocations: 432.632 MiB, 0.66% gc time)
#  24.042921 seconds (3.89 M allocations: 432.632 MiB, 0.53% gc time)
#  2
#  43.391445 seconds (112.91 M allocations: 8.201 GiB, 5.13% gc time)
#  92.495947 seconds (268.29 M allocations: 29.113 GiB, 10.07% gc time)
#  87.148321 seconds (256.03 M allocations: 27.787 GiB, 7.75% gc time)
#  3
# 128.579402 seconds (581.35 M allocations: 42.489 GiB, 8.15% gc time)
# 192.402143 seconds (699.48 M allocations: 76.884 GiB, 10.10% gc time)
# 190.379920 seconds (677.19 M allocations: 74.542 GiB, 10.55% gc time)
#  4
# 125.224900 seconds (593.77 M allocations: 43.347 GiB, 9.74% gc time)
# 200.640306 seconds (749.17 M allocations: 82.555 GiB, 12.06% gc time)
# 232.312248 seconds (858.39 M allocations: 94.749 GiB, 12.50% gc time)
#  5
# 167.177267 seconds (843.43 M allocations: 61.730 GiB, 10.64% gc time)
# 244.327777 seconds (927.47 M allocations: 102.324 GiB, 12.76% gc time)
# 254.476106 seconds (992.83 M allocations: 109.557 GiB, 12.09% gc time)
# pair0023...			 1
# - 20:34:30.800948 ERROR: nlopt failure
#  15.149286 seconds (3.39 M allocations: 257.700 MiB, 0.40% gc time)
#  21.998459 seconds (3.91 M allocations: 434.343 MiB, 0.43% gc time)
#  20.858531 seconds (3.91 M allocations: 434.343 MiB, 0.50% gc time)
#  2
#  52.269729 seconds (160.56 M allocations: 11.665 GiB, 5.71% gc time)
#  88.535756 seconds (266.32 M allocations: 28.905 GiB, 8.13% gc time)
# - 20:39:09.853670 ERROR: nlopt failure
#  95.388661 seconds (324.96 M allocations: 35.290 GiB, 9.44% gc time)
#  3
# 128.790273 seconds (566.15 M allocations: 41.368 GiB, 8.71% gc time)
# 153.625280 seconds (574.29 M allocations: 63.217 GiB, 10.26% gc time)
# 126.453176 seconds (484.06 M allocations: 53.244 GiB, 9.92% gc time)
#  4
# 122.688942 seconds (657.65 M allocations: 48.008 GiB, 9.46% gc time)
# 180.680273 seconds (772.82 M allocations: 84.637 GiB, 11.93% gc time)
# 142.337725 seconds (576.58 M allocations: 63.669 GiB, 11.75% gc time)
#  5
# 168.592985 seconds (977.72 M allocations: 71.547 GiB, 10.77% gc time)
# 271.098404 seconds (1.21 G allocations: 134.351 GiB, 10.94% gc time)
# 251.198367 seconds (1.13 G allocations: 125.555 GiB, 11.52% gc time)
# pair0024...			 1
#  14.948314 seconds (3.52 M allocations: 267.416 MiB, 0.43% gc time)
#  17.601946 seconds (3.90 M allocations: 433.487 MiB, 0.50% gc time)
#  18.951052 seconds (3.92 M allocations: 435.552 MiB, 0.47% gc time)
#  2
#  52.928587 seconds (202.96 M allocations: 14.734 GiB, 6.15% gc time)
#  80.247107 seconds (274.79 M allocations: 29.776 GiB, 8.31% gc time)
# - 21:08:56.124658 ERROR: nlopt failure
#  56.124091 seconds (225.72 M allocations: 24.488 GiB, 10.08% gc time)
#  3
#  79.768465 seconds (395.18 M allocations: 28.863 GiB, 8.45% gc time)
# 120.726782 seconds (472.63 M allocations: 51.871 GiB, 10.26% gc time)
# 120.423596 seconds (482.39 M allocations: 52.912 GiB, 10.75% gc time)
#  4
#  97.745323 seconds (511.93 M allocations: 37.364 GiB, 7.83% gc time)
# 186.842123 seconds (826.29 M allocations: 91.030 GiB, 10.86% gc time)
# 217.044326 seconds (954.59 M allocations: 105.324 GiB, 11.48% gc time)
#  5
# 135.951709 seconds (806.19 M allocations: 58.992 GiB, 8.96% gc time)
# 156.785734 seconds (718.32 M allocations: 79.161 GiB, 9.87% gc time)
# 171.015373 seconds (777.41 M allocations: 85.455 GiB, 10.32% gc time)
# pair0025...			 1
#  18.582205 seconds (7.32 M allocations: 541.813 MiB, 0.56% gc time)
#  16.511105 seconds (8.16 M allocations: 908.432 MiB, 1.08% gc time)
#  19.772330 seconds (8.16 M allocations: 908.432 MiB, 0.85% gc time)
#  2
#  85.730152 seconds (623.80 M allocations: 44.243 GiB, 10.27% gc time)
# 132.669042 seconds (671.95 M allocations: 72.956 GiB, 11.37% gc time)
# 140.514810 seconds (706.41 M allocations: 76.699 GiB, 11.56% gc time)
#  3
# - 21:38:46.123451 ERROR: nlopt failure
#  89.911622 seconds (804.09 M allocations: 57.512 GiB, 13.72% gc time)
# 186.393562 seconds (1.03 G allocations: 113.187 GiB, 12.19% gc time)
# 267.301613 seconds (1.49 G allocations: 163.903 GiB, 12.54% gc time)
#  4
# 173.585156 seconds (1.53 G allocations: 109.380 GiB, 13.11% gc time)
# 357.876846 seconds (2.00 G allocations: 220.735 GiB, 14.14% gc time)
# 339.298681 seconds (1.89 G allocations: 209.353 GiB, 13.84% gc time)
#  5
# 194.841543 seconds (1.74 G allocations: 124.870 GiB, 13.79% gc time)
# 334.515758 seconds (1.96 G allocations: 216.463 GiB, 13.63% gc time)
# 366.890466 seconds (2.12 G allocations: 234.211 GiB, 13.96% gc time)
# "{\"likelihoods\":{\"pair0007\":{\"4\":{\"<\":2385.188883001789,\"^\":2469.8921171941897,\">\":2307.5035822854015},\"2\":{\"<\":2370.430425816063,\"^\":2618.3313719689404,\">\":2374.136250049068},\"3\":{\"<\":2379.7418207046185,\"^\":2498.4970364163537,\">\":2374.0350961118356},\"5\":{\"<\":2223.8245328481216,\"^\":2436.885540701786,\">\":1458.5718675211165},\"1\":{\"<\":2466.605052721935,\"^\":2844.243363120336,\">\":2464.8888899356803}},\"pair0023\":{\"4\":{\"<\":1192.1621484436712,\"^\":1215.6630704046092,\">\":1189.3093882206192},\"2\":{\"<\":0.0,\"^\":1241.0012197531807,\">\":1186.0993725058067},\"3\":{\"<\":1190.6918252943124,\"^\":1230.3697692984183,\">\":1187.8623785654129},\"5\":{\"<\":1193.507390388223,\"^\":1204.3842685824247,\">\":1191.6682184022109},\"1\":{\"<\":1205.0035494537924,\"^\":0.0,\">\":1200.9476510385066}},\"pair0020\":{\"4\":{\"<\":848.2492838239342,\"^\":871.9005644160068,\">\":851.8279148732862},\"2\":{\"<\":874.7452122487997,\"^\":903.2765104586172,\">\":882.8812494628149},\"3\":{\"<\":854.9762976818278,\"^\":892.8976666956839,\">\":843.8815983418776},\"5\":{\"<\":870.2639631252423,\"^\":882.3438133146527,\">\":852.1001569266018},\"1\":{\"<\":978.5234532944199,\"^\":998.9382769493149,\">\":981.2521310920879}},\"pair0024\":{\"4\":{\"<\":1249.0710542827715,\"^\":1256.5358402210413,\">\":1262.0528921000705},\"2\":{\"<\":0.0,\"^\":1252.9072952295421,\">\":1248.035162703459},\"3\":{\"<\":1246.7842145255843,\"^\":1255.7034561074004,\">\":1256.9019675057375},\"5\":{\"<\":1244.7238931897707,\"^\":1261.8943861191092,\">\":1264.5448807183384},\"1\":{\"<\":1246.996208885843,\"^\":1287.1944485105907,\">\":1248.9736196626554}},\"pair0025\":{\"4\":{\"<\":2636.527562670117,\"^\":2634.717391247076,\">\":2633.5204261297836},\"2\":{\"<\":2661.737769831861,\"^\":2677.3917779279313,\">\":2656.7722374075647},\"3\":{\"<\":2649.1413562033854,\"^\":0.0,\">\":2652.728216701337},\"5\":{\"<\":2654.790240228537,\"^\":2655.77753369923,\">\":2657.9978175425263},\"1\":{\"<\":2719.4299599197616,\"^\":2846.5604022808616,\">\":2716.792185126682}},\"pair0013\":{\"4\":{\"<\":732.1752392388129,\"^\":737.5679359203986,\">\":732.593845294406},\"2\":{\"<\":740.3928990904416,\"^\":817.2619824596768,\">\":744.3687780030505},\"3\":{\"<\":741.5704864653641,\"^\":765.446293777298,\">\":736.5241496438508},\"5\":{\"<\":731.016014068836,\"^\":734.5494457054363,\">\":760.2946630409423},\"1\":{\"<\":903.3545819011697,\"^\":1116.9827326222794,\">\":0.0}},\"pair0002\":{\"4\":{\"<\":0.0,\"^\":691.213197398185,\">\":700.082475553087},\"2\":{\"<\":752.3503794928006,\"^\":781.5959374703623,\">\":755.2073255918516},\"3\":{\"<\":701.6585792974023,\"^\":724.306136365758,\">\":711.4556281953256},\"5\":{\"<\":705.4240262068535,\"^\":696.0157126283618,\">\":711.369586557852},\"1\":{\"<\":849.8406115504055,\"^\":989.5086809327146,\">\":848.5008038292517}},\"pair0018\":{\"4\":{\"<\":0.0,\"^\":554.505565254196,\">\":522.4147482858925},\"2\":{\"<\":560.5347261596291,\"^\":646.2833344830457,\">\":548.3254987153512},\"3\":{\"<\":537.4493666882187,\"^\":594.5633261287022,\">\":567.6209776811152},\"5\":{\"<\":535.2665145246648,\"^\":538.4585105098677,\">\":531.8808301239357},\"1\":{\"<\":721.0480000805286,\"^\":0.0,\">\":0.0}},\"pair0019\":{\"4\":{\"<\":339.0602992859982,\"^\":330.20135312898987,\">\":340.134608927443},\"2\":{\"<\":326.88881314429017,\"^\":344.3814701263381,\">\":333.9469033258519},\"3\":{\"<\":327.4961084563132,\"^\":323.706960395057,\">\":326.11798305108385},\"5\":{\"<\":0.0,\"^\":338.6905250957024,\">\":325.32228446610475},\"1\":{\"<\":418.5356245795822,\"^\":556.9903692996373,\">\":418.83783422340184}},\"pair0009\":{\"4\":{\"<\":2435.6396672775736,\"^\":2493.2198961980616,\">\":2430.7209660301305},\"2\":{\"<\":2499.449998186873,\"^\":2633.0148131424676,\">\":2520.107939637485},\"3\":{\"<\":2448.9831890580203,\"^\":2527.9424827971684,\">\":2437.3980715849566},\"5\":{\"<\":2233.3984059815602,\"^\":2399.4815870506777,\">\":2364.1223215586224},\"1\":{ ...
